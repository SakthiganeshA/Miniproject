# %% [markdown]
# <a href="https://colab.research.google.com/github/SakthiganeshA/Miniproject/blob/main/Mini_project_3_Corona_Vaccine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Part I: Observation Questions***
# How many distinct counties + state there (hint: unique)
# Is there any data missing for any month/day of any year?      (hint: use unique applied on date + month part of each year)
# ***Part II: Questions***
# 1. Top 10 states having highest total death in the year 2020
# 2. Top 10 states having highest total death in the year 2021
# 3. Top 10 states having highest average death in the year 2020
# 4. Top 10 states having highest average death in the year 2021
# 5. Top 10 county having highest total death in 2020 and 2021 year together
# 6. Find/print all pair of counties that have the same name but belong to two different states (hint: use pandas self join)
# 7. Print list of Top N states by the least number of death in a specific year. Also needed to be ranked.
# a) Top 10 least death states in 2020
# b) Top 10 least death states in 2021
# 8. Print Top N states in the last three months of the year 2021. Also needed to be ranked. Also right this output as a file in folder /content/drive/MyDrive/data_preprocessing with header and no index.
# a) Top 10 least death states in last three months of the year 2021
# b) Top 10 most death states in last three months of the year 2021

# %%
import pandas as pd
import glob
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
one = pd.read_csv('/us-counties.csv')
two= pd.read_csv('/us-counties-recent.csv')
merge= pd.concat([one, two])
merge.to_csv('merge.csv', index=True)

# %%
print(merge.head(10))
hi=merge.shape
print(hi)
# Out:
#          date    county    state    fips    cases  deaths
# 0  2021-12-11   Autauga  Alabama  1001.0  10596.0   158.0
# 1  2021-12-11   Baldwin  Alabama  1003.0  38307.0   591.0
# 2  2021-12-11   Barbour  Alabama  1005.0   3716.0    81.0
# 3  2021-12-11      Bibb  Alabama  1007.0   4379.0    95.0
# 4  2021-12-11    Blount  Alabama  1009.0  10857.0   193.0
# 5  2021-12-11   Bullock  Alabama  1011.0   1537.0    46.0
# 6  2021-12-11    Butler  Alabama  1013.0   3466.0   102.0
# 7  2021-12-11   Calhoun  Alabama  1015.0  22695.0   522.0
# 8  2021-12-11  Chambers  Alabama  1017.0   5830.0   143.0
# 9  2021-12-11  Cherokee  Alabama  1019.0   3230.0    64.0
# (102723, 6)

# %% [markdown]
# How many number of distinct states and distinct districts ?

# %%
State = merge["state"].unique()
print(State)
print(len(State))
# Out:
# ['Alabama' 'Alaska' 'American Samoa' 'Arizona' 'Arkansas' 'California'
#  'Colorado' 'Connecticut' 'Delaware' 'District of Columbia' 'Florida'
#  'Georgia' 'Guam' 'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas'
#  'Kentucky' 'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan'
#  'Minnesota' 'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada'
#  'New Hampshire' 'New Jersey' 'New Mexico' 'New York' 'North Carolina'
#  'North Dakota' 'Northern Mariana Islands' 'Ohio' 'Oklahoma' 'Oregon'
#  'Pennsylvania' 'Puerto Rico' 'Rhode Island' 'South Carolina'
#  'South Dakota' 'Tennessee' 'Texas' 'Utah' 'Vermont' 'Virgin Islands'
#  'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming' nan]
# 57

# %%
District= merge["county"].unique()
print(District)
print(len(District))
# Out:
# ['Autauga' 'Baldwin' 'Barbour' ... 'Washakie' 'Weston' nan]
# 1931

# %%
Total= merge["fips"].unique()
print(Total)
# Out:
# 1988

# %%
print(State,District)
# Out:
# ['Alabama' 'Alaska' 'American Samoa' 'Arizona' 'Arkansas' 'California'
#  'Colorado' 'Connecticut' 'Delaware' 'District of Columbia' 'Florida'
#  'Georgia' 'Guam' 'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas'
#  'Kentucky' 'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan'
#  'Minnesota' 'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada'
#  'New Hampshire' 'New Jersey' 'New Mexico' 'New York' 'North Carolina'
#  'North Dakota' 'Northern Mariana Islands' 'Ohio' 'Oklahoma' 'Oregon'
#  'Pennsylvania' 'Puerto Rico' 'Rhode Island' 'South Carolina'
#  'South Dakota' 'Tennessee' 'Texas' 'Utah' 'Vermont' 'Virgin Islands'
#  'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming' nan] ['Autauga' 'Baldwin' 'Barbour' ... 'Washakie' 'Weston' nan]

# %% [markdown]
# Is there any data missing for any day/month of any year?

# %%
null_dates = merge[merge['date'].isnull()]['date']
print(null_dates)
# Out:
# Series([], Name: date, dtype: object)

# %%
if 'Year' in merge.columns:
    null_Years = merge[merge['Year'].isnull()]['Year']
    print(null_Years)
else:
    print("Column 'Year' not found in DataFrame.")
# Out:
# Column 'Year' not found in DataFrame.

# %%
merge['year'] = merge['date'].dt.year
print(merge['year'])
# Out:
# 0        2020
# 1        2020
# 2        2020
# 3        2020
# 4        2020
#          ...
# 97515    2022
# 97516    2022
# 97517    2022
# 97518    2022
# 97519    2022
# Name: year, Length: 283929, dtype: int32

# %%
merge['date'] = pd.to_datetime(merge['date'])
print(merge['date'].dtype)
# Out:
# datetime64[ns]

# %%
print(merge.head(10))
# Out:
#          date    county    state    fips    cases  deaths
# 0  2021-12-11   Autauga  Alabama  1001.0  10596.0   158.0
# 1  2021-12-11   Baldwin  Alabama  1003.0  38307.0   591.0
# 2  2021-12-11   Barbour  Alabama  1005.0   3716.0    81.0
# 3  2021-12-11      Bibb  Alabama  1007.0   4379.0    95.0
# 4  2021-12-11    Blount  Alabama  1009.0  10857.0   193.0
# 5  2021-12-11   Bullock  Alabama  1011.0   1537.0    46.0
# 6  2021-12-11    Butler  Alabama  1013.0   3466.0   102.0
# 7  2021-12-11   Calhoun  Alabama  1015.0  22695.0   522.0
# 8  2021-12-11  Chambers  Alabama  1017.0   5830.0   143.0
# 9  2021-12-11  Cherokee  Alabama  1019.0   3230.0    64.0

# %% [markdown]
# The top 10 states having highest total death in year 2021

# %%
high_death = merge[merge['date'] == 2020]
state_deaths = high_death.groupby('state')['deaths'].sum()
top_10_states = state_deaths.sort_values(ascending=False).head(10)
print(top_10_states)
# Out:
# Series([], Name: deaths, dtype: float64)

# %% [markdown]
# The top 10 states having highest total death in year 2021

# %%
high_death2 = merge[merge['date'] == 2021]
state_deaths = high_death.groupby('state')['deaths'].sum()
top_10_states = state_deaths.sort_values(ascending=False).head(10)
print(top_10_states)
# Out:
# Series([], Name: deaths, dtype: float64)

# %% [markdown]
# Top 10 states having highest average death in the year 2020

# %%
highavg_2020=merge[merge['year']==2020]
state_deaths = highavg_2020.groupby(['state'])['deaths'].mean()
top_10_states = state_deaths.sort_values(ascending=False).head(10)
print(top_10_states)
# Out:
# state
# New York                283.842492
# New Jersey              224.033788
# Connecticut             181.897866
# Massachusetts           162.983179
# District of Columbia    151.807229
# Puerto Rico              60.342105
# Rhode Island             39.578431
# Michigan                 37.090857
# Maryland                 37.051412
# Delaware                 33.833948
# Name: deaths, dtype: float64

# %% [markdown]
# Top 10 states having highest average death in the year 2020

# %%
highavg_2021=merge[merge['year']==2021]
state_deaths = highavg_2021.groupby(['state'])['deaths'].mean()
top_10_states = state_deaths.sort_values(ascending=False).head(10)
print(top_10_states)
# Out:
# state
# Puerto Rico             3285.904762
# Arizona                 1573.000000
# Massachusetts           1328.523810
# California              1311.647783
# New Jersey              1307.796537
# District of Columbia    1205.904762
# Connecticut             1006.190476
# New York                1004.131363
# Florida                  915.585434
# Delaware                 562.714286
# Name: deaths, dtype: float64

# %% [markdown]
# Top 10 county having highest total death in 2020 and 2021 year together.

# %%
df_2021_2020 = merge[(merge['year'] == 2021) | (merge['year'] == 2021)]
county_deaths = df_2021_2020.groupby('county')['deaths'].sum()
top_10_counties = county_deaths.sort_values(ascending=False).head(10)
print(top_10_counties)
# Out:
# county
# New York City    737403.0
# Los Angeles      576918.0
# Maricopa         281682.0
# Cook             260513.0
# Harris           205344.0
# Orange           200160.0
# Miami-Dade       193643.0
# Jefferson        193039.0
# Montgomery       179540.0
# Wayne            169512.0
# Name: deaths, dtype: float64

# %% [markdown]
# Find/print all pair of counties that have the same name but belong to two different states.

# %%
grouped = merge.groupby('county')['state'].apply(set).reset_index()
pairs = []
for _, row in grouped.iterrows():
    county_name = row['county']
    states = row['state']
    for i in range(len(states)):
        for j in range(i + 1, len(states)):
            pairs.append((list(states)[i], list(states)[j]))
            print(list(states)[i], list(states)[j])
for pair in pairs:
    print(pair)
# Out:
# Streaming output truncated to the last 5000 lines.
# ('Arkansas', 'Minnesota')
# ('Arkansas', 'Alabama')
# ('Arkansas', 'North Carolina')
# ('Arkansas', 'Colorado')
# ('Arkansas', 'Illinois')
# ('Arkansas', 'Louisiana')
# ('Arkansas', 'Michigan')
# ('Arkansas', 'Indiana')
# ('Arkansas', 'Oregon')
# ('Iowa', 'West Virginia')
# ('Iowa', 'South Dakota')
# ('Iowa', 'Tennessee')
# ('Iowa', 'Ohio')
# ('Iowa', 'Florida')
# ('Iowa', 'Kansas')
# ('Iowa', 'Missouri')
# ('Iowa', 'Kentucky')
# ('Iowa', 'Texas')
# ('Iowa', 'Minnesota')
# ('Iowa', 'Alabama')
# ('Iowa', 'North Carolina')
# ('Iowa', 'Colorado')
# ('Iowa', 'Illinois')
# ('Iowa', 'Louisiana')
# ('Iowa', 'Michigan')
# ('Iowa', 'Indiana')
# ('Iowa', 'Oregon')
# ('West Virginia', 'South Dakota')
# ('West Virginia', 'Tennessee')
# ('West Virginia', 'Ohio')
# ('West Virginia', 'Florida')
# ('West Virginia', 'Kansas')
# ('West Virginia', 'Missouri')
# ('West Virginia', 'Kentucky')
# ('West Virginia', 'Texas')
# ('West Virginia', 'Minnesota')
# ('West Virginia', 'Alabama')
# ('West Virginia', 'North Carolina')
# ('West Virginia', 'Colorado')
# ('West Virginia', 'Illinois')
# ('West Virginia', 'Louisiana')
# ('West Virginia', 'Michigan')
# ('West Virginia', 'Indiana')
# ('West Virginia', 'Oregon')
# ('South Dakota', 'Tennessee')
# ('South Dakota', 'Ohio')
# ('South Dakota', 'Florida')
# ('South Dakota', 'Kansas')
# ('South Dakota', 'Missouri')
# ('South Dakota', 'Kentucky')
# ('South Dakota', 'Texas')
# ('South Dakota', 'Minnesota')
# ('South Dakota', 'Alabama')
# ('South Dakota', 'North Carolina')
# ('South Dakota', 'Colorado')
# ('South Dakota', 'Illinois')
# ('South Dakota', 'Louisiana')
# ('South Dakota', 'Michigan')
# ('South Dakota', 'Indiana')
# ('South Dakota', 'Oregon')
# ('Tennessee', 'Ohio')
# ('Tennessee', 'Florida')
# ('Tennessee', 'Kansas')
# ('Tennessee', 'Missouri')
# ('Tennessee', 'Kentucky')
# ('Tennessee', 'Texas')
# ('Tennessee', 'Minnesota')
# ('Tennessee', 'Alabama')
# ('Tennessee', 'North Carolina')
# ('Tennessee', 'Colorado')
# ('Tennessee', 'Illinois')
# ('Tennessee', 'Louisiana')
# ('Tennessee', 'Michigan')
# ('Tennessee', 'Indiana')
# ('Tennessee', 'Oregon')
# ('Ohio', 'Florida')
# ('Ohio', 'Kansas')
# ('Ohio', 'Missouri')
# ('Ohio', 'Kentucky')
# ('Ohio', 'Texas')
# ('Ohio', 'Minnesota')
# ('Ohio', 'Alabama')
# ('Ohio', 'North Carolina')
# ('Ohio', 'Colorado')
# ('Ohio', 'Illinois')
# ('Ohio', 'Louisiana')
# ('Ohio', 'Michigan')
# ('Ohio', 'Indiana')
# ('Ohio', 'Oregon')
# ('Florida', 'Kansas')
# ('Florida', 'Missouri')
# ('Florida', 'Kentucky')
# ('Florida', 'Texas')
# ('Florida', 'Minnesota')
# ('Florida', 'Alabama')
# ('Florida', 'North Carolina')
# ('Florida', 'Colorado')
# ('Florida', 'Illinois')
# ('Florida', 'Louisiana')
# ('Florida', 'Michigan')
# ('Florida', 'Indiana')
# ('Florida', 'Oregon')
# ('Kansas', 'Missouri')
# ('Kansas', 'Kentucky')
# ('Kansas', 'Texas')
# ('Kansas', 'Minnesota')
# ('Kansas', 'Alabama')
# ('Kansas', 'North Carolina')
# ('Kansas', 'Colorado')
# ('Kansas', 'Illinois')
# ('Kansas', 'Louisiana')
# ('Kansas', 'Michigan')
# ('Kansas', 'Indiana')
# ('Kansas', 'Oregon')
# ('Missouri', 'Kentucky')
# ('Missouri', 'Texas')
# ('Missouri', 'Minnesota')
# ('Missouri', 'Alabama')
# ('Missouri', 'North Carolina')
# ('Missouri', 'Colorado')
# ('Missouri', 'Illinois')
# ('Missouri', 'Louisiana')
# ('Missouri', 'Michigan')
# ('Missouri', 'Indiana')
# ('Missouri', 'Oregon')
# ('Kentucky', 'Texas')
# ('Kentucky', 'Minnesota')
# ('Kentucky', 'Alabama')
# ('Kentucky', 'North Carolina')
# ('Kentucky', 'Colorado')
# ('Kentucky', 'Illinois')
# ('Kentucky', 'Louisiana')
# ('Kentucky', 'Michigan')
# ('Kentucky', 'Indiana')
# ('Kentucky', 'Oregon')
# ('Texas', 'Minnesota')
# ('Texas', 'Alabama')
# ('Texas', 'North Carolina')
# ('Texas', 'Colorado')
# ('Texas', 'Illinois')
# ('Texas', 'Louisiana')
# ('Texas', 'Michigan')
# ('Texas', 'Indiana')
# ('Texas', 'Oregon')
# ('Minnesota', 'Alabama')
# ('Minnesota', 'North Carolina')
# ('Minnesota', 'Colorado')
# ('Minnesota', 'Illinois')
# ('Minnesota', 'Louisiana')
# ('Minnesota', 'Michigan')
# ('Minnesota', 'Indiana')
# ('Minnesota', 'Oregon')
# ('Alabama', 'North Carolina')
# ('Alabama', 'Colorado')
# ('Alabama', 'Illinois')
# ('Alabama', 'Louisiana')
# ('Alabama', 'Michigan')
# ('Alabama', 'Indiana')
# ('Alabama', 'Oregon')
# ('North Carolina', 'Colorado')
# ('North Carolina', 'Illinois')
# ('North Carolina', 'Louisiana')
# ('North Carolina', 'Michigan')
# ('North Carolina', 'Indiana')
# ('North Carolina', 'Oregon')
# ('Colorado', 'Illinois')
# ('Colorado', 'Louisiana')
# ('Colorado', 'Michigan')
# ('Colorado', 'Indiana')
# ('Colorado', 'Oregon')
# ('Illinois', 'Louisiana')
# ('Illinois', 'Michigan')
# ('Illinois', 'Indiana')
# ('Illinois', 'Oregon')
# ('Louisiana', 'Michigan')
# ('Louisiana', 'Indiana')
# ('Louisiana', 'Oregon')
# ('Michigan', 'Indiana')
# ('Michigan', 'Oregon')
# ('Indiana', 'Oregon')
# ('Georgia', 'Missouri')
# ('Georgia', 'Iowa')
# ('Georgia', 'Illinois')
# ('Georgia', 'South Carolina')
# ('Georgia', 'Indiana')
# ('Georgia', 'Texas')
# ('Georgia', 'Mississippi')
# ('Missouri', 'Iowa')
# ('Missouri', 'Illinois')
# ('Missouri', 'South Carolina')
# ('Missouri', 'Indiana')
# ('Missouri', 'Texas')
# ('Missouri', 'Mississippi')
# ('Iowa', 'Illinois')
# ('Iowa', 'South Carolina')
# ('Iowa', 'Indiana')
# ('Iowa', 'Texas')
# ('Iowa', 'Mississippi')
# ('Illinois', 'South Carolina')
# ('Illinois', 'Indiana')
# ('Illinois', 'Texas')
# ('Illinois', 'Mississippi')
# ('South Carolina', 'Indiana')
# ('South Carolina', 'Texas')
# ('South Carolina', 'Mississippi')
# ('Indiana', 'Texas')
# ('Indiana', 'Mississippi')
# ('Texas', 'Mississippi')
# ('Texas', 'Georgia')
# ('Georgia', 'Wisconsin')
# ('Georgia', 'Oklahoma')
# ('Georgia', 'Montana')
# ('Georgia', 'Mississippi')
# ('Georgia', 'Pennsylvania')
# ('Georgia', 'Arkansas')
# ('Georgia', 'Iowa')
# ('Georgia', 'West Virginia')
# ('Georgia', 'Tennessee')
# ('Georgia', 'Ohio')
# ('Georgia', 'Florida')
# ('Georgia', 'Kansas')
# ('Georgia', 'Missouri')
# ('Georgia', 'Kentucky')
# ('Georgia', 'Texas')
# ('Georgia', 'Idaho')
# ('Georgia', 'New York')
# ('Georgia', 'Alabama')
# ('Georgia', 'Washington')
# ('Georgia', 'Colorado')
# ('Georgia', 'Louisiana')
# ('Georgia', 'Illinois')
# ('Georgia', 'Nebraska')
# ('Georgia', 'Indiana')
# ('Georgia', 'Oregon')
# ('Wisconsin', 'Oklahoma')
# ('Wisconsin', 'Montana')
# ('Wisconsin', 'Mississippi')
# ('Wisconsin', 'Pennsylvania')
# ('Wisconsin', 'Arkansas')
# ('Wisconsin', 'Iowa')
# ('Wisconsin', 'West Virginia')
# ('Wisconsin', 'Tennessee')
# ('Wisconsin', 'Ohio')
# ('Wisconsin', 'Florida')
# ('Wisconsin', 'Kansas')
# ('Wisconsin', 'Missouri')
# ('Wisconsin', 'Kentucky')
# ('Wisconsin', 'Texas')
# ('Wisconsin', 'Idaho')
# ('Wisconsin', 'New York')
# ('Wisconsin', 'Alabama')
# ('Wisconsin', 'Washington')
# ('Wisconsin', 'Colorado')
# ('Wisconsin', 'Louisiana')
# ('Wisconsin', 'Illinois')
# ('Wisconsin', 'Nebraska')
# ('Wisconsin', 'Indiana')
# ('Wisconsin', 'Oregon')
# ('Oklahoma', 'Montana')
# ('Oklahoma', 'Mississippi')
# ('Oklahoma', 'Pennsylvania')
# ('Oklahoma', 'Arkansas')
# ('Oklahoma', 'Iowa')
# ('Oklahoma', 'West Virginia')
# ('Oklahoma', 'Tennessee')
# ('Oklahoma', 'Ohio')
# ('Oklahoma', 'Florida')
# ('Oklahoma', 'Kansas')
# ('Oklahoma', 'Missouri')
# ('Oklahoma', 'Kentucky')
# ('Oklahoma', 'Texas')
# ('Oklahoma', 'Idaho')
# ('Oklahoma', 'New York')
# ('Oklahoma', 'Alabama')
# ('Oklahoma', 'Washington')
# ('Oklahoma', 'Colorado')
# ('Oklahoma', 'Louisiana')
# ('Oklahoma', 'Illinois')
# ('Oklahoma', 'Nebraska')
# ('Oklahoma', 'Indiana')
# ('Oklahoma', 'Oregon')
# ('Montana', 'Mississippi')
# ('Montana', 'Pennsylvania')
# ('Montana', 'Arkansas')
# ('Montana', 'Iowa')
# ('Montana', 'West Virginia')
# ('Montana', 'Tennessee')
# ('Montana', 'Ohio')
# ('Montana', 'Florida')
# ('Montana', 'Kansas')
# ('Montana', 'Missouri')
# ('Montana', 'Kentucky')
# ('Montana', 'Texas')
# ('Montana', 'Idaho')
# ('Montana', 'New York')
# ('Montana', 'Alabama')
# ('Montana', 'Washington')
# ('Montana', 'Colorado')
# ('Montana', 'Louisiana')
# ('Montana', 'Illinois')
# ('Montana', 'Nebraska')
# ('Montana', 'Indiana')
# ('Montana', 'Oregon')
# ('Mississippi', 'Pennsylvania')
# ('Mississippi', 'Arkansas')
# ('Mississippi', 'Iowa')
# ('Mississippi', 'West Virginia')
# ('Mississippi', 'Tennessee')
# ('Mississippi', 'Ohio')
# ('Mississippi', 'Florida')
# ('Mississippi', 'Kansas')
# ('Mississippi', 'Missouri')
# ('Mississippi', 'Kentucky')
# ('Mississippi', 'Texas')
# ('Mississippi', 'Idaho')
# ('Mississippi', 'New York')
# ('Mississippi', 'Alabama')
# ('Mississippi', 'Washington')
# ('Mississippi', 'Colorado')
# ('Mississippi', 'Louisiana')
# ('Mississippi', 'Illinois')
# ('Mississippi', 'Nebraska')
# ('Mississippi', 'Indiana')
# ('Mississippi', 'Oregon')
# ('Pennsylvania', 'Arkansas')
# ('Pennsylvania', 'Iowa')
# ('Pennsylvania', 'West Virginia')
# ('Pennsylvania', 'Tennessee')
# ('Pennsylvania', 'Ohio')
# ('Pennsylvania', 'Florida')
# ('Pennsylvania', 'Kansas')
# ('Pennsylvania', 'Missouri')
# ('Pennsylvania', 'Kentucky')
# ('Pennsylvania', 'Texas')
# ('Pennsylvania', 'Idaho')
# ('Pennsylvania', 'New York')
# ('Pennsylvania', 'Alabama')
# ('Pennsylvania', 'Washington')
# ('Pennsylvania', 'Colorado')
# ('Pennsylvania', 'Louisiana')
# ('Pennsylvania', 'Illinois')
# ('Pennsylvania', 'Nebraska')
# ('Pennsylvania', 'Indiana')
# ('Pennsylvania', 'Oregon')
# ('Arkansas', 'Iowa')
# ('Arkansas', 'West Virginia')
# ('Arkansas', 'Tennessee')
# ('Arkansas', 'Ohio')
# ('Arkansas', 'Florida')
# ('Arkansas', 'Kansas')
# ('Arkansas', 'Missouri')
# ('Arkansas', 'Kentucky')
# ('Arkansas', 'Texas')
# ('Arkansas', 'Idaho')
# ('Arkansas', 'New York')
# ('Arkansas', 'Alabama')
# ('Arkansas', 'Washington')
# ('Arkansas', 'Colorado')
# ('Arkansas', 'Louisiana')
# ('Arkansas', 'Illinois')
# ('Arkansas', 'Nebraska')
# ('Arkansas', 'Indiana')
# ('Arkansas', 'Oregon')
# ('Iowa', 'West Virginia')
# ('Iowa', 'Tennessee')
# ('Iowa', 'Ohio')
# ('Iowa', 'Florida')
# ('Iowa', 'Kansas')
# ('Iowa', 'Missouri')
# ('Iowa', 'Kentucky')
# ('Iowa', 'Texas')
# ('Iowa', 'Idaho')
# ('Iowa', 'New York')
# ('Iowa', 'Alabama')
# ('Iowa', 'Washington')
# ('Iowa', 'Colorado')
# ('Iowa', 'Louisiana')
# ('Iowa', 'Illinois')
# ('Iowa', 'Nebraska')
# ('Iowa', 'Indiana')
# ('Iowa', 'Oregon')
# ('West Virginia', 'Tennessee')
# ('West Virginia', 'Ohio')
# ('West Virginia', 'Florida')
# ('West Virginia', 'Kansas')
# ('West Virginia', 'Missouri')
# ('West Virginia', 'Kentucky')
# ('West Virginia', 'Texas')
# ('West Virginia', 'Idaho')
# ('West Virginia', 'New York')
# ('West Virginia', 'Alabama')
# ('West Virginia', 'Washington')
# ('West Virginia', 'Colorado')
# ('West Virginia', 'Louisiana')
# ('West Virginia', 'Illinois')
# ('West Virginia', 'Nebraska')
# ('West Virginia', 'Indiana')
# ('West Virginia', 'Oregon')
# ('Tennessee', 'Ohio')
# ('Tennessee', 'Florida')
# ('Tennessee', 'Kansas')
# ('Tennessee', 'Missouri')
# ('Tennessee', 'Kentucky')
# ('Tennessee', 'Texas')
# ('Tennessee', 'Idaho')
# ('Tennessee', 'New York')
# ('Tennessee', 'Alabama')
# ('Tennessee', 'Washington')
# ('Tennessee', 'Colorado')
# ('Tennessee', 'Louisiana')
# ('Tennessee', 'Illinois')
# ('Tennessee', 'Nebraska')
# ('Tennessee', 'Indiana')
# ('Tennessee', 'Oregon')
# ('Ohio', 'Florida')
# ('Ohio', 'Kansas')
# ('Ohio', 'Missouri')
# ('Ohio', 'Kentucky')
# ('Ohio', 'Texas')
# ('Ohio', 'Idaho')
# ('Ohio', 'New York')
# ('Ohio', 'Alabama')
# ('Ohio', 'Washington')
# ('Ohio', 'Colorado')
# ('Ohio', 'Louisiana')
# ('Ohio', 'Illinois')
# ('Ohio', 'Nebraska')
# ('Ohio', 'Indiana')
# ('Ohio', 'Oregon')
# ('Florida', 'Kansas')
# ('Florida', 'Missouri')
# ('Florida', 'Kentucky')
# ('Florida', 'Texas')
# ('Florida', 'Idaho')
# ('Florida', 'New York')
# ('Florida', 'Alabama')
# ('Florida', 'Washington')
# ('Florida', 'Colorado')
# ('Florida', 'Louisiana')
# ('Florida', 'Illinois')
# ('Florida', 'Nebraska')
# ('Florida', 'Indiana')
# ('Florida', 'Oregon')
# ('Kansas', 'Missouri')
# ('Kansas', 'Kentucky')
# ('Kansas', 'Texas')
# ('Kansas', 'Idaho')
# ('Kansas', 'New York')
# ('Kansas', 'Alabama')
# ('Kansas', 'Washington')
# ('Kansas', 'Colorado')
# ('Kansas', 'Louisiana')
# ('Kansas', 'Illinois')
# ('Kansas', 'Nebraska')
# ('Kansas', 'Indiana')
# ('Kansas', 'Oregon')
# ('Missouri', 'Kentucky')
# ('Missouri', 'Texas')
# ('Missouri', 'Idaho')
# ('Missouri', 'New York')
# ('Missouri', 'Alabama')
# ('Missouri', 'Washington')
# ('Missouri', 'Colorado')
# ('Missouri', 'Louisiana')
# ('Missouri', 'Illinois')
# ('Missouri', 'Nebraska')
# ('Missouri', 'Indiana')
# ('Missouri', 'Oregon')
# ('Kentucky', 'Texas')
# ('Kentucky', 'Idaho')
# ('Kentucky', 'New York')
# ('Kentucky', 'Alabama')
# ('Kentucky', 'Washington')
# ('Kentucky', 'Colorado')
# ('Kentucky', 'Louisiana')
# ('Kentucky', 'Illinois')
# ('Kentucky', 'Nebraska')
# ('Kentucky', 'Indiana')
# ('Kentucky', 'Oregon')
# ('Texas', 'Idaho')
# ('Texas', 'New York')
# ('Texas', 'Alabama')
# ('Texas', 'Washington')
# ('Texas', 'Colorado')
# ('Texas', 'Louisiana')
# ('Texas', 'Illinois')
# ('Texas', 'Nebraska')
# ('Texas', 'Indiana')
# ('Texas', 'Oregon')
# ('Idaho', 'New York')
# ('Idaho', 'Alabama')
# ('Idaho', 'Washington')
# ('Idaho', 'Colorado')
# ('Idaho', 'Louisiana')
# ('Idaho', 'Illinois')
# ('Idaho', 'Nebraska')
# ('Idaho', 'Indiana')
# ('Idaho', 'Oregon')
# ('New York', 'Alabama')
# ('New York', 'Washington')
# ('New York', 'Colorado')
# ('New York', 'Louisiana')
# ('New York', 'Illinois')
# ('New York', 'Nebraska')
# ('New York', 'Indiana')
# ('New York', 'Oregon')
# ('Alabama', 'Washington')
# ('Alabama', 'Colorado')
# ('Alabama', 'Louisiana')
# ('Alabama', 'Illinois')
# ('Alabama', 'Nebraska')
# ('Alabama', 'Indiana')
# ('Alabama', 'Oregon')
# ('Washington', 'Colorado')
# ('Washington', 'Louisiana')
# ('Washington', 'Illinois')
# ('Washington', 'Nebraska')
# ('Washington', 'Indiana')
# ('Washington', 'Oregon')
# ('Colorado', 'Louisiana')
# ('Colorado', 'Illinois')
# ('Colorado', 'Nebraska')
# ('Colorado', 'Indiana')
# ('Colorado', 'Oregon')
# ('Louisiana', 'Illinois')
# ('Louisiana', 'Nebraska')
# ('Louisiana', 'Indiana')
# ('Louisiana', 'Oregon')
# ('Illinois', 'Nebraska')
# ('Illinois', 'Indiana')
# ('Illinois', 'Oregon')
# ('Nebraska', 'Indiana')
# ('Nebraska', 'Oregon')
# ('Indiana', 'Oregon')
# ('Louisiana', 'Mississippi')
# ('Georgia', 'Missouri')
# ('Georgia', 'Arkansas')
# ('Georgia', 'Iowa')
# ('Georgia', 'Illinois')
# ('Georgia', 'Nebraska')
# ('Georgia', 'Wyoming')
# ('Georgia', 'Tennessee')
# ('Georgia', 'Kentucky')
# ('Georgia', 'Texas')
# ('Georgia', 'Indiana')
# ('Georgia', 'Kansas')
# ('Missouri', 'Arkansas')
# ('Missouri', 'Iowa')
# ('Missouri', 'Illinois')
# ('Missouri', 'Nebraska')
# ('Missouri', 'Wyoming')
# ('Missouri', 'Tennessee')
# ('Missouri', 'Kentucky')
# ('Missouri', 'Texas')
# ('Missouri', 'Indiana')
# ('Missouri', 'Kansas')
# ('Arkansas', 'Iowa')
# ('Arkansas', 'Illinois')
# ('Arkansas', 'Nebraska')
# ('Arkansas', 'Wyoming')
# ('Arkansas', 'Tennessee')
# ('Arkansas', 'Kentucky')
# ('Arkansas', 'Texas')
# ('Arkansas', 'Indiana')
# ('Arkansas', 'Kansas')
# ('Iowa', 'Illinois')
# ('Iowa', 'Nebraska')
# ('Iowa', 'Wyoming')
# ('Iowa', 'Tennessee')
# ('Iowa', 'Kentucky')
# ('Iowa', 'Texas')
# ('Iowa', 'Indiana')
# ('Iowa', 'Kansas')
# ('Illinois', 'Nebraska')
# ('Illinois', 'Wyoming')
# ('Illinois', 'Tennessee')
# ('Illinois', 'Kentucky')
# ('Illinois', 'Texas')
# ('Illinois', 'Indiana')
# ('Illinois', 'Kansas')
# ('Nebraska', 'Wyoming')
# ('Nebraska', 'Tennessee')
# ('Nebraska', 'Kentucky')
# ('Nebraska', 'Texas')
# ('Nebraska', 'Indiana')
# ('Nebraska', 'Kansas')
# ('Wyoming', 'Tennessee')
# ('Wyoming', 'Kentucky')
# ('Wyoming', 'Texas')
# ('Wyoming', 'Indiana')
# ('Wyoming', 'Kansas')
# ('Tennessee', 'Kentucky')
# ('Tennessee', 'Texas')
# ('Tennessee', 'Indiana')
# ('Tennessee', 'Kansas')
# ('Kentucky', 'Texas')
# ('Kentucky', 'Indiana')
# ('Kentucky', 'Kansas')
# ('Texas', 'Indiana')
# ('Texas', 'Kansas')
# ('Indiana', 'Kansas')
# ('North Carolina', 'Oklahoma')
# ('Georgia', 'North Carolina')
# ('Georgia', 'Iowa')
# ('Georgia', 'South Dakota')
# ('Georgia', 'Texas')
# ('Georgia', 'Mississippi')
# ('North Carolina', 'Iowa')
# ('North Carolina', 'South Dakota')
# ('North Carolina', 'Texas')
# ('North Carolina', 'Mississippi')
# ('Iowa', 'South Dakota')
# ('Iowa', 'Texas')
# ('Iowa', 'Mississippi')
# ('South Dakota', 'Texas')
# ('South Dakota', 'Mississippi')
# ('Texas', 'Mississippi')
# ('Illinois', 'Utah')
# ('Texas', 'Illinois')
# ('Maryland', 'Delaware')
# ('Maryland', 'Rhode Island')
# ('Maryland', 'Michigan')
# ('Maryland', 'Texas')
# ('Delaware', 'Rhode Island')
# ('Delaware', 'Michigan')
# ('Delaware', 'Texas')
# ('Rhode Island', 'Michigan')
# ('Rhode Island', 'Texas')
# ('Michigan', 'Texas')
# ('Texas', 'Washington')
# ('Kansas', 'Colorado')
# ('Kansas', 'Oklahoma')
# ('Colorado', 'Oklahoma')
# ('Maine', 'Missouri')
# ('Maine', 'Illinois')
# ('Maine', 'Nebraska')
# ('Maine', 'Tennessee')
# ('Maine', 'Ohio')
# ('Maine', 'Indiana')
# ('Maine', 'Texas')
# ('Maine', 'Kentucky')
# ('Missouri', 'Illinois')
# ('Missouri', 'Nebraska')
# ('Missouri', 'Tennessee')
# ('Missouri', 'Ohio')
# ('Missouri', 'Indiana')
# ('Missouri', 'Texas')
# ('Missouri', 'Kentucky')
# ('Illinois', 'Nebraska')
# ('Illinois', 'Tennessee')
# ('Illinois', 'Ohio')
# ('Illinois', 'Indiana')
# ('Illinois', 'Texas')
# ('Illinois', 'Kentucky')
# ('Nebraska', 'Tennessee')
# ('Nebraska', 'Ohio')
# ('Nebraska', 'Indiana')
# ('Nebraska', 'Texas')
# ('Nebraska', 'Kentucky')
# ('Tennessee', 'Ohio')
# ('Tennessee', 'Indiana')
# ('Tennessee', 'Texas')
# ('Tennessee', 'Kentucky')
# ('Ohio', 'Indiana')
# ('Ohio', 'Texas')
# ('Ohio', 'Kentucky')
# ('Indiana', 'Texas')
# ('Indiana', 'Kentucky')
# ('Texas', 'Kentucky')
# ('Illinois', 'Louisiana')
# ('Missouri', 'Wisconsin')
# ('Missouri', 'Arkansas')
# ('Missouri', 'Louisiana')
# ('Missouri', 'Florida')
# ('Missouri', 'Mississippi')
# ('Wisconsin', 'Arkansas')
# ('Wisconsin', 'Louisiana')
# ('Wisconsin', 'Florida')
# ('Wisconsin', 'Mississippi')
# ('Arkansas', 'Louisiana')
# ('Arkansas', 'Florida')
# ('Arkansas', 'Mississippi')
# ('Louisiana', 'Florida')
# ('Louisiana', 'Mississippi')
# ('Florida', 'Mississippi')
# ('Colorado', 'Illinois')
# ('Colorado', 'South Dakota')
# ('Colorado', 'Michigan')
# ('Colorado', 'Tennessee')
# ('Colorado', 'Ohio')
# ('Colorado', 'Indiana')
# ('Colorado', 'Florida')
# ('Colorado', 'Montana')
# ('Colorado', 'California')
# ('Colorado', 'Minnesota')
# ('Colorado', 'Oregon')
# ('Illinois', 'South Dakota')
# ('Illinois', 'Michigan')
# ('Illinois', 'Tennessee')
# ('Illinois', 'Ohio')
# ('Illinois', 'Indiana')
# ('Illinois', 'Florida')
# ('Illinois', 'Montana')
# ('Illinois', 'California')
# ('Illinois', 'Minnesota')
# ('Illinois', 'Oregon')
# ('South Dakota', 'Michigan')
# ('South Dakota', 'Tennessee')
# ('South Dakota', 'Ohio')
# ('South Dakota', 'Indiana')
# ('South Dakota', 'Florida')
# ('South Dakota', 'Montana')
# ('South Dakota', 'California')
# ('South Dakota', 'Minnesota')
# ('South Dakota', 'Oregon')
# ('Michigan', 'Tennessee')
# ('Michigan', 'Ohio')
# ('Michigan', 'Indiana')
# ('Michigan', 'Florida')
# ('Michigan', 'Montana')
# ('Michigan', 'California')
# ('Michigan', 'Minnesota')
# ('Michigan', 'Oregon')
# ('Tennessee', 'Ohio')
# ('Tennessee', 'Indiana')
# ('Tennessee', 'Florida')
# ('Tennessee', 'Montana')
# ('Tennessee', 'California')
# ('Tennessee', 'Minnesota')
# ('Tennessee', 'Oregon')
# ('Ohio', 'Indiana')
# ('Ohio', 'Florida')
# ('Ohio', 'Montana')
# ('Ohio', 'California')
# ('Ohio', 'Minnesota')
# ('Ohio', 'Oregon')
# ('Indiana', 'Florida')
# ('Indiana', 'Montana')
# ('Indiana', 'California')
# ('Indiana', 'Minnesota')
# ('Indiana', 'Oregon')
# ('Florida', 'Montana')
# ('Florida', 'California')
# ('Florida', 'Minnesota')
# ('Florida', 'Oregon')
# ('Montana', 'California')
# ('Montana', 'Minnesota')
# ('Montana', 'Oregon')
# ('California', 'Minnesota')
# ('California', 'Oregon')
# ('Minnesota', 'Oregon')
# ('Texas', 'Georgia')
# ('Texas', 'Alabama')
# ('Texas', 'Mississippi')
# ('Georgia', 'Alabama')
# ('Georgia', 'Mississippi')
# ('Alabama', 'Mississippi')
# ('Nebraska', 'Pennsylvania')
# ('Nebraska', 'Virginia')
# ('Nebraska', 'South Carolina')
# ('Pennsylvania', 'Virginia')
# ('Pennsylvania', 'South Carolina')
# ('Virginia', 'South Carolina')
# ('Kansas', 'Oregon')
# ('Tennessee', 'Alabama')
# ('Tennessee', 'Mississippi')
# ('Alabama', 'Mississippi')
# ('Georgia', 'South Carolina')
# ('Missouri', 'Arkansas')
# ('Missouri', 'South Dakota')
# ('Missouri', 'Illinois')
# ('Missouri', 'Tennessee')
# ('Missouri', 'Ohio')
# ('Missouri', 'Indiana')
# ('Missouri', 'Kentucky')
# ('Missouri', 'Mississippi')
# ('Missouri', 'Pennsylvania')
# ('Missouri', 'Alabama')
# ('Arkansas', 'South Dakota')
# ('Arkansas', 'Illinois')
# ('Arkansas', 'Tennessee')
# ('Arkansas', 'Ohio')
# ('Arkansas', 'Indiana')
# ('Arkansas', 'Kentucky')
# ('Arkansas', 'Mississippi')
# ('Arkansas', 'Pennsylvania')
# ('Arkansas', 'Alabama')
# ('South Dakota', 'Illinois')
# ('South Dakota', 'Tennessee')
# ('South Dakota', 'Ohio')
# ('South Dakota', 'Indiana')
# ('South Dakota', 'Kentucky')
# ('South Dakota', 'Mississippi')
# ('South Dakota', 'Pennsylvania')
# ('South Dakota', 'Alabama')
# ('Illinois', 'Tennessee')
# ('Illinois', 'Ohio')
# ('Illinois', 'Indiana')
# ('Illinois', 'Kentucky')
# ('Illinois', 'Mississippi')
# ('Illinois', 'Pennsylvania')
# ('Illinois', 'Alabama')
# ('Tennessee', 'Ohio')
# ('Tennessee', 'Indiana')
# ('Tennessee', 'Kentucky')
# ('Tennessee', 'Mississippi')
# ('Tennessee', 'Pennsylvania')
# ('Tennessee', 'Alabama')
# ('Ohio', 'Indiana')
# ('Ohio', 'Kentucky')
# ('Ohio', 'Mississippi')
# ('Ohio', 'Pennsylvania')
# ('Ohio', 'Alabama')
# ('Indiana', 'Kentucky')
# ('Indiana', 'Mississippi')
# ('Indiana', 'Pennsylvania')
# ('Indiana', 'Alabama')
# ('Kentucky', 'Mississippi')
# ('Kentucky', 'Pennsylvania')
# ('Kentucky', 'Alabama')
# ('Mississippi', 'Pennsylvania')
# ('Mississippi', 'Alabama')
# ('Pennsylvania', 'Alabama')
# ('Georgia', 'North Carolina')
# ('Georgia', 'Arkansas')
# ('Georgia', 'Iowa')
# ('Georgia', 'Illinois')
# ('Georgia', 'South Carolina')
# ('Georgia', 'Texas')
# ('Georgia', 'Kentucky')
# ('Georgia', 'Florida')
# ('Georgia', 'Mississippi')
# ('Georgia', 'Virginia')
# ('Georgia', 'Alabama')
# ('North Carolina', 'Arkansas')
# ('North Carolina', 'Iowa')
# ('North Carolina', 'Illinois')
# ('North Carolina', 'South Carolina')
# ('North Carolina', 'Texas')
# ('North Carolina', 'Kentucky')
# ('North Carolina', 'Florida')
# ('North Carolina', 'Mississippi')
# ('North Carolina', 'Virginia')
# ('North Carolina', 'Alabama')
# ('Arkansas', 'Iowa')
# ('Arkansas', 'Illinois')
# ('Arkansas', 'South Carolina')
# ('Arkansas', 'Texas')
# ('Arkansas', 'Kentucky')
# ('Arkansas', 'Florida')
# ('Arkansas', 'Mississippi')
# ('Arkansas', 'Virginia')
# ('Arkansas', 'Alabama')
# ('Iowa', 'Illinois')
# ('Iowa', 'South Carolina')
# ('Iowa', 'Texas')
# ('Iowa', 'Kentucky')
# ('Iowa', 'Florida')
# ('Iowa', 'Mississippi')
# ('Iowa', 'Virginia')
# ('Iowa', 'Alabama')
# ('Illinois', 'South Carolina')
# ('Illinois', 'Texas')
# ('Illinois', 'Kentucky')
# ('Illinois', 'Florida')
# ('Illinois', 'Mississippi')
# ('Illinois', 'Virginia')
# ('Illinois', 'Alabama')
# ('South Carolina', 'Texas')
# ('South Carolina', 'Kentucky')
# ('South Carolina', 'Florida')
# ('South Carolina', 'Mississippi')
# ('South Carolina', 'Virginia')
# ('South Carolina', 'Alabama')
# ('Texas', 'Kentucky')
# ('Texas', 'Florida')
# ('Texas', 'Mississippi')
# ('Texas', 'Virginia')
# ('Texas', 'Alabama')
# ('Kentucky', 'Florida')
# ('Kentucky', 'Mississippi')
# ('Kentucky', 'Virginia')
# ('Kentucky', 'Alabama')
# ('Florida', 'Mississippi')
# ('Florida', 'Virginia')
# ('Florida', 'Alabama')
# ('Mississippi', 'Virginia')
# ('Mississippi', 'Alabama')
# ('Virginia', 'Alabama')
# ('Texas', 'Florida')
# ('Washington', 'Missouri')
# ('Washington', 'West Virginia')
# ('Washington', 'Tennessee')
# ('Washington', 'Kentucky')
# ('Washington', 'Idaho')
# ('Washington', 'New York')
# ('Missouri', 'West Virginia')
# ('Missouri', 'Tennessee')
# ('Missouri', 'Kentucky')
# ('Missouri', 'Idaho')
# ('Missouri', 'New York')
# ('West Virginia', 'Tennessee')
# ('West Virginia', 'Kentucky')
# ('West Virginia', 'Idaho')
# ('West Virginia', 'New York')
# ('Tennessee', 'Kentucky')
# ('Tennessee', 'Idaho')
# ('Tennessee', 'New York')
# ('Kentucky', 'Idaho')
# ('Kentucky', 'New York')
# ('Idaho', 'New York')
# ('Texas', 'Florida')
# ('Texas', 'Georgia')
# ('Texas', 'Montana')
# ('Florida', 'Georgia')
# ('Florida', 'Montana')
# ('Georgia', 'Montana')
# ('Texas', 'Alabama')
# ('Georgia', 'Wisconsin')
# ('Georgia', 'Oklahoma')
# ('Georgia', 'Montana')
# ('Georgia', 'Mississippi')
# ('Georgia', 'Maine')
# ('Georgia', 'Arkansas')
# ('Georgia', 'South Dakota')
# ('Georgia', 'West Virginia')
# ('Georgia', 'Tennessee')
# ('Georgia', 'Kansas')
# ('Georgia', 'Missouri')
# ('Georgia', 'Kentucky')
# ('Georgia', 'Idaho')
# ('Georgia', 'Nevada')
# ('Georgia', 'Minnesota')
# ('Georgia', 'New Mexico')
# ('Georgia', 'North Carolina')
# ('Georgia', 'Washington')
# ('Georgia', 'Colorado')
# ('Georgia', 'Louisiana')
# ('Georgia', 'Nebraska')
# ('Georgia', 'Wyoming')
# ('Georgia', 'Oregon')
# ('Wisconsin', 'Oklahoma')
# ('Wisconsin', 'Montana')
# ('Wisconsin', 'Mississippi')
# ('Wisconsin', 'Maine')
# ('Wisconsin', 'Arkansas')
# ('Wisconsin', 'South Dakota')
# ('Wisconsin', 'West Virginia')
# ('Wisconsin', 'Tennessee')
# ('Wisconsin', 'Kansas')
# ('Wisconsin', 'Missouri')
# ('Wisconsin', 'Kentucky')
# ('Wisconsin', 'Idaho')
# ('Wisconsin', 'Nevada')
# ('Wisconsin', 'Minnesota')
# ('Wisconsin', 'New Mexico')
# ('Wisconsin', 'North Carolina')
# ('Wisconsin', 'Washington')
# ('Wisconsin', 'Colorado')
# ('Wisconsin', 'Louisiana')
# ('Wisconsin', 'Nebraska')
# ('Wisconsin', 'Wyoming')
# ('Wisconsin', 'Oregon')
# ('Oklahoma', 'Montana')
# ('Oklahoma', 'Mississippi')
# ('Oklahoma', 'Maine')
# ('Oklahoma', 'Arkansas')
# ('Oklahoma', 'South Dakota')
# ('Oklahoma', 'West Virginia')
# ('Oklahoma', 'Tennessee')
# ('Oklahoma', 'Kansas')
# ('Oklahoma', 'Missouri')
# ('Oklahoma', 'Kentucky')
# ('Oklahoma', 'Idaho')
# ('Oklahoma', 'Nevada')
# ('Oklahoma', 'Minnesota')
# ('Oklahoma', 'New Mexico')
# ('Oklahoma', 'North Carolina')
# ('Oklahoma', 'Washington')
# ('Oklahoma', 'Colorado')
# ('Oklahoma', 'Louisiana')
# ('Oklahoma', 'Nebraska')
# ('Oklahoma', 'Wyoming')
# ('Oklahoma', 'Oregon')
# ('Montana', 'Mississippi')
# ('Montana', 'Maine')
# ('Montana', 'Arkansas')
# ('Montana', 'South Dakota')
# ('Montana', 'West Virginia')
# ('Montana', 'Tennessee')
# ('Montana', 'Kansas')
# ('Montana', 'Missouri')
# ('Montana', 'Kentucky')
# ('Montana', 'Idaho')
# ('Montana', 'Nevada')
# ('Montana', 'Minnesota')
# ('Montana', 'New Mexico')
# ('Montana', 'North Carolina')
# ('Montana', 'Washington')
# ('Montana', 'Colorado')
# ('Montana', 'Louisiana')
# ('Montana', 'Nebraska')
# ('Montana', 'Wyoming')
# ('Montana', 'Oregon')
# ('Mississippi', 'Maine')
# ('Mississippi', 'Arkansas')
# ('Mississippi', 'South Dakota')
# ('Mississippi', 'West Virginia')
# ('Mississippi', 'Tennessee')
# ('Mississippi', 'Kansas')
# ('Mississippi', 'Missouri')
# ('Mississippi', 'Kentucky')
# ('Mississippi', 'Idaho')
# ('Mississippi', 'Nevada')
# ('Mississippi', 'Minnesota')
# ('Mississippi', 'New Mexico')
# ('Mississippi', 'North Carolina')
# ('Mississippi', 'Washington')
# ('Mississippi', 'Colorado')
# ('Mississippi', 'Louisiana')
# ('Mississippi', 'Nebraska')
# ('Mississippi', 'Wyoming')
# ('Mississippi', 'Oregon')
# ('Maine', 'Arkansas')
# ('Maine', 'South Dakota')
# ('Maine', 'West Virginia')
# ('Maine', 'Tennessee')
# ('Maine', 'Kansas')
# ('Maine', 'Missouri')
# ('Maine', 'Kentucky')
# ('Maine', 'Idaho')
# ('Maine', 'Nevada')
# ('Maine', 'Minnesota')
# ('Maine', 'New Mexico')
# ('Maine', 'North Carolina')
# ('Maine', 'Washington')
# ('Maine', 'Colorado')
# ('Maine', 'Louisiana')
# ('Maine', 'Nebraska')
# ('Maine', 'Wyoming')
# ('Maine', 'Oregon')
# ('Arkansas', 'South Dakota')
# ('Arkansas', 'West Virginia')
# ('Arkansas', 'Tennessee')
# ('Arkansas', 'Kansas')
# ('Arkansas', 'Missouri')
# ('Arkansas', 'Kentucky')
# ('Arkansas', 'Idaho')
# ('Arkansas', 'Nevada')
# ('Arkansas', 'Minnesota')
# ('Arkansas', 'New Mexico')
# ('Arkansas', 'North Carolina')
# ('Arkansas', 'Washington')
# ('Arkansas', 'Colorado')
# ('Arkansas', 'Louisiana')
# ('Arkansas', 'Nebraska')
# ('Arkansas', 'Wyoming')
# ('Arkansas', 'Oregon')
# ('South Dakota', 'West Virginia')
# ('South Dakota', 'Tennessee')
# ('South Dakota', 'Kansas')
# ('South Dakota', 'Missouri')
# ('South Dakota', 'Kentucky')
# ('South Dakota', 'Idaho')
# ('South Dakota', 'Nevada')
# ('South Dakota', 'Minnesota')
# ('South Dakota', 'New Mexico')
# ('South Dakota', 'North Carolina')
# ('South Dakota', 'Washington')
# ('South Dakota', 'Colorado')
# ('South Dakota', 'Louisiana')
# ('South Dakota', 'Nebraska')
# ('South Dakota', 'Wyoming')
# ('South Dakota', 'Oregon')
# ('West Virginia', 'Tennessee')
# ('West Virginia', 'Kansas')
# ('West Virginia', 'Missouri')
# ('West Virginia', 'Kentucky')
# ('West Virginia', 'Idaho')
# ('West Virginia', 'Nevada')
# ('West Virginia', 'Minnesota')
# ('West Virginia', 'New Mexico')
# ('West Virginia', 'North Carolina')
# ('West Virginia', 'Washington')
# ('West Virginia', 'Colorado')
# ('West Virginia', 'Louisiana')
# ('West Virginia', 'Nebraska')
# ('West Virginia', 'Wyoming')
# ('West Virginia', 'Oregon')
# ('Tennessee', 'Kansas')
# ('Tennessee', 'Missouri')
# ('Tennessee', 'Kentucky')
# ('Tennessee', 'Idaho')
# ('Tennessee', 'Nevada')
# ('Tennessee', 'Minnesota')
# ('Tennessee', 'New Mexico')
# ('Tennessee', 'North Carolina')
# ('Tennessee', 'Washington')
# ('Tennessee', 'Colorado')
# ('Tennessee', 'Louisiana')
# ('Tennessee', 'Nebraska')
# ('Tennessee', 'Wyoming')
# ('Tennessee', 'Oregon')
# ('Kansas', 'Missouri')
# ('Kansas', 'Kentucky')
# ('Kansas', 'Idaho')
# ('Kansas', 'Nevada')
# ('Kansas', 'Minnesota')
# ('Kansas', 'New Mexico')
# ('Kansas', 'North Carolina')
# ('Kansas', 'Washington')
# ('Kansas', 'Colorado')
# ('Kansas', 'Louisiana')
# ('Kansas', 'Nebraska')
# ('Kansas', 'Wyoming')
# ('Kansas', 'Oregon')
# ('Missouri', 'Kentucky')
# ('Missouri', 'Idaho')
# ('Missouri', 'Nevada')
# ('Missouri', 'Minnesota')
# ('Missouri', 'New Mexico')
# ('Missouri', 'North Carolina')
# ('Missouri', 'Washington')
# ('Missouri', 'Colorado')
# ('Missouri', 'Louisiana')
# ('Missouri', 'Nebraska')
# ('Missouri', 'Wyoming')
# ('Missouri', 'Oregon')
# ('Kentucky', 'Idaho')
# ('Kentucky', 'Nevada')
# ('Kentucky', 'Minnesota')
# ('Kentucky', 'New Mexico')
# ('Kentucky', 'North Carolina')
# ('Kentucky', 'Washington')
# ('Kentucky', 'Colorado')
# ('Kentucky', 'Louisiana')
# ('Kentucky', 'Nebraska')
# ('Kentucky', 'Wyoming')
# ('Kentucky', 'Oregon')
# ('Idaho', 'Nevada')
# ('Idaho', 'Minnesota')
# ('Idaho', 'New Mexico')
# ('Idaho', 'North Carolina')
# ('Idaho', 'Washington')
# ('Idaho', 'Colorado')
# ('Idaho', 'Louisiana')
# ('Idaho', 'Nebraska')
# ('Idaho', 'Wyoming')
# ('Idaho', 'Oregon')
# ('Nevada', 'Minnesota')
# ('Nevada', 'New Mexico')
# ('Nevada', 'North Carolina')
# ('Nevada', 'Washington')
# ('Nevada', 'Colorado')
# ('Nevada', 'Louisiana')
# ('Nevada', 'Nebraska')
# ('Nevada', 'Wyoming')
# ('Nevada', 'Oregon')
# ('Minnesota', 'New Mexico')
# ('Minnesota', 'North Carolina')
# ('Minnesota', 'Washington')
# ('Minnesota', 'Colorado')
# ('Minnesota', 'Louisiana')
# ('Minnesota', 'Nebraska')
# ('Minnesota', 'Wyoming')
# ('Minnesota', 'Oregon')
# ('New Mexico', 'North Carolina')
# ('New Mexico', 'Washington')
# ('New Mexico', 'Colorado')
# ('New Mexico', 'Louisiana')
# ('New Mexico', 'Nebraska')
# ('New Mexico', 'Wyoming')
# ('New Mexico', 'Oregon')
# ('North Carolina', 'Washington')
# ('North Carolina', 'Colorado')
# ('North Carolina', 'Louisiana')
# ('North Carolina', 'Nebraska')
# ('North Carolina', 'Wyoming')
# ('North Carolina', 'Oregon')
# ('Washington', 'Colorado')
# ('Washington', 'Louisiana')
# ('Washington', 'Nebraska')
# ('Washington', 'Wyoming')
# ('Washington', 'Oregon')
# ('Colorado', 'Louisiana')
# ('Colorado', 'Nebraska')
# ('Colorado', 'Wyoming')
# ('Colorado', 'Oregon')
# ('Louisiana', 'Nebraska')
# ('Louisiana', 'Wyoming')
# ('Louisiana', 'Oregon')
# ('Nebraska', 'Wyoming')
# ('Nebraska', 'Oregon')
# ('Wyoming', 'Oregon')
# ('Kansas', 'Missouri')
# ('Kansas', 'Oregon')
# ('Kansas', 'Iowa')
# ('Missouri', 'Oregon')
# ('Missouri', 'Iowa')
# ('Oregon', 'Iowa')
# ('Missouri', 'Louisiana')
# ('Missouri', 'Illinois')
# ('Missouri', 'Michigan')
# ('Missouri', 'Kentucky')
# ('Missouri', 'New York')
# ('Louisiana', 'Illinois')
# ('Louisiana', 'Michigan')
# ('Louisiana', 'Kentucky')
# ('Louisiana', 'New York')
# ('Illinois', 'Michigan')
# ('Illinois', 'Kentucky')
# ('Illinois', 'New York')
# ('Michigan', 'Kentucky')
# ('Michigan', 'New York')
# ('Kentucky', 'New York')
# ('Arkansas', 'North Dakota')
# ('Arkansas', 'Oklahoma')
# ('Arkansas', 'Colorado')
# ('Arkansas', 'West Virginia')
# ('Arkansas', 'Illinois')
# ('Arkansas', 'Nebraska')
# ('Arkansas', 'Ohio')
# ('Arkansas', 'Kentucky')
# ('Arkansas', 'Kansas')
# ('North Dakota', 'Oklahoma')
# ('North Dakota', 'Colorado')
# ('North Dakota', 'West Virginia')
# ('North Dakota', 'Illinois')
# ('North Dakota', 'Nebraska')
# ('North Dakota', 'Ohio')
# ('North Dakota', 'Kentucky')
# ('North Dakota', 'Kansas')
# ('Oklahoma', 'Colorado')
# ('Oklahoma', 'West Virginia')
# ('Oklahoma', 'Illinois')
# ('Oklahoma', 'Nebraska')
# ('Oklahoma', 'Ohio')
# ('Oklahoma', 'Kentucky')
# ('Oklahoma', 'Kansas')
# ('Colorado', 'West Virginia')
# ('Colorado', 'Illinois')
# ('Colorado', 'Nebraska')
# ('Colorado', 'Ohio')
# ('Colorado', 'Kentucky')
# ('Colorado', 'Kansas')
# ('West Virginia', 'Illinois')
# ('West Virginia', 'Nebraska')
# ('West Virginia', 'Ohio')
# ('West Virginia', 'Kentucky')
# ('West Virginia', 'Kansas')
# ('Illinois', 'Nebraska')
# ('Illinois', 'Ohio')
# ('Illinois', 'Kentucky')
# ('Illinois', 'Kansas')
# ('Nebraska', 'Ohio')
# ('Nebraska', 'Kentucky')
# ('Nebraska', 'Kansas')
# ('Ohio', 'Kentucky')
# ('Ohio', 'Kansas')
# ('Kentucky', 'Kansas')
# ('Virginia', 'Iowa')
# ('Georgia', 'Alabama')
# ('Georgia', 'Mississippi')
# ('Alabama', 'Mississippi')
# ('Iowa', 'Ohio')
# ('Iowa', 'Nevada')
# ('Iowa', 'Kentucky')
# ('Iowa', 'Kansas')
# ('Iowa', 'Minnesota')
# ('Nevada', 'Kentucky')
# ('Nevada', 'Kansas')
# ('Nevada', 'Minnesota')
# ('Kentucky', 'Kansas')
# ('Kentucky', 'Minnesota')
# ('Kansas', 'Minnesota')
# ('Georgia', 'North Carolina')
# ('Georgia', 'Missouri')
# ('Georgia', 'Illinois')
# ('Georgia', 'Tennessee')
# ('Georgia', 'Alabama')
# ('North Carolina', 'Missouri')
# ('North Carolina', 'Illinois')
# ('North Carolina', 'Tennessee')
# ('North Carolina', 'Alabama')
# ('Missouri', 'Illinois')
# ('Missouri', 'Tennessee')
# ('Missouri', 'Alabama')
# ('Illinois', 'Tennessee')
# ('Illinois', 'Alabama')
# ('Tennessee', 'Alabama')
# ('Georgia', 'Montana')
# ('Georgia', 'Mississippi')
# ('Georgia', 'Arkansas')
# ('Georgia', 'Iowa')
# ('Georgia', 'Tennessee')
# ('Georgia', 'Ohio')
# ('Georgia', 'Florida')
# ('Georgia', 'Missouri')
# ('Georgia', 'Kentucky')
# ('Georgia', 'Idaho')
# ('Georgia', 'Texas')
# ('Georgia', 'New York')
# ('Georgia', 'Virginia')
# ('Georgia', 'Alabama')
# ('Georgia', 'North Carolina')
# ('Georgia', 'Illinois')
# ('Georgia', 'Nebraska')
# ('Georgia', 'Louisiana')
# ('Georgia', 'Indiana')
# ('Montana', 'Mississippi')
# ('Montana', 'Arkansas')
# ('Montana', 'Iowa')
# ('Montana', 'Tennessee')
# ('Montana', 'Ohio')
# ('Montana', 'Florida')
# ('Montana', 'Missouri')
# ('Montana', 'Kentucky')
# ('Montana', 'Idaho')
# ('Montana', 'Texas')
# ('Montana', 'New York')
# ('Montana', 'Virginia')
# ('Montana', 'Alabama')
# ('Montana', 'North Carolina')
# ('Montana', 'Illinois')
# ('Montana', 'Nebraska')
# ('Montana', 'Louisiana')
# ('Montana', 'Indiana')
# ('Mississippi', 'Arkansas')
# ('Mississippi', 'Iowa')
# ('Mississippi', 'Tennessee')
# ('Mississippi', 'Ohio')
# ('Mississippi', 'Florida')
# ('Mississippi', 'Missouri')
# ('Mississippi', 'Kentucky')
# ('Mississippi', 'Idaho')
# ('Mississippi', 'Texas')
# ('Mississippi', 'New York')
# ('Mississippi', 'Virginia')
# ('Mississippi', 'Alabama')
# ('Mississippi', 'North Carolina')
# ('Mississippi', 'Illinois')
# ('Mississippi', 'Nebraska')
# ('Mississippi', 'Louisiana')
# ('Mississippi', 'Indiana')
# ('Arkansas', 'Iowa')
# ('Arkansas', 'Tennessee')
# ('Arkansas', 'Ohio')
# ('Arkansas', 'Florida')
# ('Arkansas', 'Missouri')
# ('Arkansas', 'Kentucky')
# ('Arkansas', 'Idaho')
# ('Arkansas', 'Texas')
# ('Arkansas', 'New York')
# ('Arkansas', 'Virginia')
# ('Arkansas', 'Alabama')
# ('Arkansas', 'North Carolina')
# ('Arkansas', 'Illinois')
# ('Arkansas', 'Nebraska')
# ('Arkansas', 'Louisiana')
# ('Arkansas', 'Indiana')
# ('Iowa', 'Tennessee')
# ('Iowa', 'Ohio')
# ('Iowa', 'Florida')
# ('Iowa', 'Missouri')
# ('Iowa', 'Kentucky')
# ('Iowa', 'Idaho')
# ('Iowa', 'Texas')
# ('Iowa', 'New York')
# ('Iowa', 'Virginia')
# ('Iowa', 'Alabama')
# ('Iowa', 'North Carolina')
# ('Iowa', 'Illinois')
# ('Iowa', 'Nebraska')
# ('Iowa', 'Louisiana')
# ('Iowa', 'Indiana')
# ('Tennessee', 'Ohio')
# ('Tennessee', 'Florida')
# ('Tennessee', 'Missouri')
# ('Tennessee', 'Kentucky')
# ('Tennessee', 'Idaho')
# ('Tennessee', 'Texas')
# ('Tennessee', 'New York')
# ('Tennessee', 'Virginia')
# ('Tennessee', 'Alabama')
# ('Tennessee', 'North Carolina')
# ('Tennessee', 'Illinois')
# ('Tennessee', 'Nebraska')
# ('Tennessee', 'Louisiana')
# ('Tennessee', 'Indiana')
# ('Ohio', 'Florida')
# ('Ohio', 'Missouri')
# ('Ohio', 'Kentucky')
# ('Ohio', 'Idaho')
# ('Ohio', 'Texas')
# ('Ohio', 'New York')
# ('Ohio', 'Virginia')
# ('Ohio', 'Alabama')
# ('Ohio', 'North Carolina')
# ('Ohio', 'Illinois')
# ('Ohio', 'Nebraska')
# ('Ohio', 'Louisiana')
# ('Ohio', 'Indiana')
# ('Florida', 'Missouri')
# ('Florida', 'Kentucky')
# ('Florida', 'Idaho')
# ('Florida', 'Texas')
# ('Florida', 'New York')
# ('Florida', 'Virginia')
# ('Florida', 'Alabama')
# ('Florida', 'North Carolina')
# ('Florida', 'Illinois')
# ('Florida', 'Nebraska')
# ('Florida', 'Louisiana')
# ('Florida', 'Indiana')
# ('Missouri', 'Kentucky')
# ('Missouri', 'Idaho')
# ('Missouri', 'Texas')
# ('Missouri', 'New York')
# ('Missouri', 'Virginia')
# ('Missouri', 'Alabama')
# ('Missouri', 'North Carolina')
# ('Missouri', 'Illinois')
# ('Missouri', 'Nebraska')
# ('Missouri', 'Louisiana')
# ('Missouri', 'Indiana')
# ('Kentucky', 'Idaho')
# ('Kentucky', 'Texas')
# ('Kentucky', 'New York')
# ('Kentucky', 'Virginia')
# ('Kentucky', 'Alabama')
# ('Kentucky', 'North Carolina')
# ('Kentucky', 'Illinois')
# ('Kentucky', 'Nebraska')
# ('Kentucky', 'Louisiana')
# ('Kentucky', 'Indiana')
# ('Idaho', 'Texas')
# ('Idaho', 'New York')
# ('Idaho', 'Virginia')
# ('Idaho', 'Alabama')
# ('Idaho', 'North Carolina')
# ('Idaho', 'Illinois')
# ('Idaho', 'Nebraska')
# ('Idaho', 'Louisiana')
# ('Idaho', 'Indiana')
# ('Texas', 'New York')
# ('Texas', 'Virginia')
# ('Texas', 'Alabama')
# ('Texas', 'North Carolina')
# ('Texas', 'Illinois')
# ('Texas', 'Nebraska')
# ('Texas', 'Louisiana')
# ('Texas', 'Indiana')
# ('New York', 'Virginia')
# ('New York', 'Alabama')
# ('New York', 'North Carolina')
# ('New York', 'Illinois')
# ('New York', 'Nebraska')
# ('New York', 'Louisiana')
# ('New York', 'Indiana')
# ('Virginia', 'Alabama')
# ('Virginia', 'North Carolina')
# ('Virginia', 'Illinois')
# ('Virginia', 'Nebraska')
# ('Virginia', 'Louisiana')
# ('Virginia', 'Indiana')
# ('Alabama', 'North Carolina')
# ('Alabama', 'Illinois')
# ('Alabama', 'Nebraska')
# ('Alabama', 'Louisiana')
# ('Alabama', 'Indiana')
# ('North Carolina', 'Illinois')
# ('North Carolina', 'Nebraska')
# ('North Carolina', 'Louisiana')
# ('North Carolina', 'Indiana')
# ('Illinois', 'Nebraska')
# ('Illinois', 'Louisiana')
# ('Illinois', 'Indiana')
# ('Nebraska', 'Louisiana')
# ('Nebraska', 'Indiana')
# ('Louisiana', 'Indiana')
# ('Georgia', 'Missouri')
# ('Georgia', 'Arkansas')
# ('Georgia', 'Iowa')
# ('Georgia', 'West Virginia')
# ('Georgia', 'Illinois')
# ('Georgia', 'Tennessee')
# ('Georgia', 'Ohio')
# ('Georgia', 'Indiana')
# ('Georgia', 'South Carolina')
# ('Georgia', 'Florida')
# ('Georgia', 'Kentucky')
# ('Georgia', 'Texas')
# ('Georgia', 'Mississippi')
# ('Georgia', 'Kansas')
# ('Georgia', 'Oregon')
# ('Georgia', 'Alabama')
# ('Missouri', 'Arkansas')
# ('Missouri', 'Iowa')
# ('Missouri', 'West Virginia')
# ('Missouri', 'Illinois')
# ('Missouri', 'Tennessee')
# ('Missouri', 'Ohio')
# ('Missouri', 'Indiana')
# ('Missouri', 'South Carolina')
# ('Missouri', 'Florida')
# ('Missouri', 'Kentucky')
# ('Missouri', 'Texas')
# ('Missouri', 'Mississippi')
# ('Missouri', 'Kansas')
# ('Missouri', 'Oregon')
# ('Missouri', 'Alabama')
# ('Arkansas', 'Iowa')
# ('Arkansas', 'West Virginia')
# ('Arkansas', 'Illinois')
# ('Arkansas', 'Tennessee')
# ('Arkansas', 'Ohio')
# ('Arkansas', 'Indiana')
# ('Arkansas', 'South Carolina')
# ('Arkansas', 'Florida')
# ('Arkansas', 'Kentucky')
# ('Arkansas', 'Texas')
# ('Arkansas', 'Mississippi')
# ('Arkansas', 'Kansas')
# ('Arkansas', 'Oregon')
# ('Arkansas', 'Alabama')
# ('Iowa', 'West Virginia')
# ('Iowa', 'Illinois')
# ('Iowa', 'Tennessee')
# ('Iowa', 'Ohio')
# ('Iowa', 'Indiana')
# ('Iowa', 'South Carolina')
# ('Iowa', 'Florida')
# ('Iowa', 'Kentucky')
# ('Iowa', 'Texas')
# ('Iowa', 'Mississippi')
# ('Iowa', 'Kansas')
# ('Iowa', 'Oregon')
# ('Iowa', 'Alabama')
# ('West Virginia', 'Illinois')
# ('West Virginia', 'Tennessee')
# ('West Virginia', 'Ohio')
# ('West Virginia', 'Indiana')
# ('West Virginia', 'South Carolina')
# ('West Virginia', 'Florida')
# ('West Virginia', 'Kentucky')
# ('West Virginia', 'Texas')
# ('West Virginia', 'Mississippi')
# ('West Virginia', 'Kansas')
# ('West Virginia', 'Oregon')
# ('West Virginia', 'Alabama')
# ('Illinois', 'Tennessee')
# ('Illinois', 'Ohio')
# ('Illinois', 'Indiana')
# ('Illinois', 'South Carolina')
# ('Illinois', 'Florida')
# ('Illinois', 'Kentucky')
# ('Illinois', 'Texas')
# ('Illinois', 'Mississippi')
# ('Illinois', 'Kansas')
# ('Illinois', 'Oregon')
# ('Illinois', 'Alabama')
# ('Tennessee', 'Ohio')
# ('Tennessee', 'Indiana')
# ('Tennessee', 'South Carolina')
# ('Tennessee', 'Florida')
# ('Tennessee', 'Kentucky')
# ('Tennessee', 'Texas')
# ('Tennessee', 'Mississippi')
# ('Tennessee', 'Kansas')
# ('Tennessee', 'Oregon')
# ('Tennessee', 'Alabama')
# ('Ohio', 'Indiana')
# ('Ohio', 'South Carolina')
# ('Ohio', 'Florida')
# ('Ohio', 'Kentucky')
# ('Ohio', 'Texas')
# ('Ohio', 'Mississippi')
# ('Ohio', 'Kansas')
# ('Ohio', 'Oregon')
# ('Ohio', 'Alabama')
# ('Indiana', 'South Carolina')
# ('Indiana', 'Florida')
# ('Indiana', 'Kentucky')
# ('Indiana', 'Texas')
# ('Indiana', 'Mississippi')
# ('Indiana', 'Kansas')
# ('Indiana', 'Oregon')
# ('Indiana', 'Alabama')
# ('South Carolina', 'Florida')
# ('South Carolina', 'Kentucky')
# ('South Carolina', 'Texas')
# ('South Carolina', 'Mississippi')
# ('South Carolina', 'Kansas')
# ('South Carolina', 'Oregon')
# ('South Carolina', 'Alabama')
# ('Florida', 'Kentucky')
# ('Florida', 'Texas')
# ('Florida', 'Mississippi')
# ('Florida', 'Kansas')
# ('Florida', 'Oregon')
# ('Florida', 'Alabama')
# ('Kentucky', 'Texas')
# ('Kentucky', 'Mississippi')
# ('Kentucky', 'Kansas')
# ('Kentucky', 'Oregon')
# ('Kentucky', 'Alabama')
# ('Texas', 'Mississippi')
# ('Texas', 'Kansas')
# ('Texas', 'Oregon')
# ('Texas', 'Alabama')
# ('Mississippi', 'Kansas')
# ('Mississippi', 'Oregon')
# ('Mississippi', 'Alabama')
# ('Kansas', 'Oregon')
# ('Kansas', 'Alabama')
# ('Oregon', 'Alabama')
# ('Michigan', 'Wisconsin')
# ('Iowa', 'Oklahoma')
# ('Iowa', 'West Virginia')
# ('Iowa', 'Illinois')
# ('Iowa', 'South Dakota')
# ('Iowa', 'Tennessee')
# ('Iowa', 'Kentucky')
# ('Iowa', 'Indiana')
# ('Iowa', 'Mississippi')
# ('Iowa', 'Kansas')
# ('Iowa', 'Minnesota')
# ('Iowa', 'Alabama')
# ('Oklahoma', 'West Virginia')
# ('Oklahoma', 'Illinois')
# ('Oklahoma', 'South Dakota')
# ('Oklahoma', 'Tennessee')
# ('Oklahoma', 'Kentucky')
# ('Oklahoma', 'Indiana')
# ('Oklahoma', 'Mississippi')
# ('Oklahoma', 'Kansas')
# ('Oklahoma', 'Minnesota')
# ('Oklahoma', 'Alabama')
# ('West Virginia', 'Illinois')
# ('West Virginia', 'South Dakota')
# ('West Virginia', 'Tennessee')
# ('West Virginia', 'Kentucky')
# ('West Virginia', 'Indiana')
# ('West Virginia', 'Mississippi')
# ('West Virginia', 'Kansas')
# ('West Virginia', 'Minnesota')
# ('West Virginia', 'Alabama')
# ('Illinois', 'South Dakota')
# ('Illinois', 'Tennessee')
# ('Illinois', 'Kentucky')
# ('Illinois', 'Indiana')
# ('Illinois', 'Mississippi')
# ('Illinois', 'Kansas')
# ('Illinois', 'Minnesota')
# ('Illinois', 'Alabama')
# ('South Dakota', 'Tennessee')
# ('South Dakota', 'Kentucky')
# ('South Dakota', 'Indiana')
# ('South Dakota', 'Mississippi')
# ('South Dakota', 'Kansas')
# ('South Dakota', 'Minnesota')
# ('South Dakota', 'Alabama')
# ('Tennessee', 'Kentucky')
# ('Tennessee', 'Indiana')
# ('Tennessee', 'Mississippi')
# ('Tennessee', 'Kansas')
# ('Tennessee', 'Minnesota')
# ('Tennessee', 'Alabama')
# ('Kentucky', 'Indiana')
# ('Kentucky', 'Mississippi')
# ('Kentucky', 'Kansas')
# ('Kentucky', 'Minnesota')
# ('Kentucky', 'Alabama')
# ('Indiana', 'Mississippi')
# ('Indiana', 'Kansas')
# ('Indiana', 'Minnesota')
# ('Indiana', 'Alabama')
# ('Mississippi', 'Kansas')
# ('Mississippi', 'Minnesota')
# ('Mississippi', 'Alabama')
# ('Kansas', 'Minnesota')
# ('Kansas', 'Alabama')
# ('Minnesota', 'Alabama')
# ('North Carolina', 'Kentucky')
# ('North Carolina', 'Texas')
# ('North Carolina', 'Indiana')
# ('North Carolina', 'Florida')
# ('North Carolina', 'Minnesota')
# ('Kentucky', 'Texas')
# ('Kentucky', 'Indiana')
# ('Kentucky', 'Florida')
# ('Kentucky', 'Minnesota')
# ('Texas', 'Indiana')
# ('Texas', 'Florida')
# ('Texas', 'Minnesota')
# ('Indiana', 'Florida')
# ('Indiana', 'Minnesota')
# ('Florida', 'Minnesota')
# ('Washington', 'West Virginia')
# ('Washington', 'Illinois')
# ('Washington', 'Michigan')
# ('Washington', 'Kentucky')
# ('Washington', 'Texas')
# ('West Virginia', 'Illinois')
# ('West Virginia', 'Michigan')
# ('West Virginia', 'Kentucky')
# ('West Virginia', 'Texas')
# ('Illinois', 'Michigan')
# ('Illinois', 'Kentucky')
# ('Illinois', 'Texas')
# ('Michigan', 'Kentucky')
# ('Michigan', 'Texas')
# ('Kentucky', 'Texas')
# ('West Virginia', 'North Carolina')
# ('Illinois', 'North Dakota')
# ('Georgia', 'North Dakota')
# ('Georgia', 'Oklahoma')
# ('North Dakota', 'Oklahoma')
# ('Illinois', 'North Dakota')
# ('Illinois', 'Kentucky')
# ('North Dakota', 'Kentucky')
# ('Kansas', 'South Dakota')
# ('Kansas', 'Nebraska')
# ('South Dakota', 'Nebraska')
# ('Kansas', 'South Dakota')
# ('Kansas', 'Kentucky')
# ('South Dakota', 'Kentucky')
# ('North Carolina', 'Virginia')
# ('Texas', 'Ohio')
# ('Tennessee', 'Ohio')
# ('Texas', 'Illinois')
# ('Michigan', 'Wisconsin')
# ('Missouri', 'New Jersey')
# ('Missouri', 'North Dakota')
# ('Missouri', 'West Virginia')
# ('Missouri', 'Illinois')
# ('Missouri', 'Kentucky')
# ('Missouri', 'Ohio')
# ('Missouri', 'Pennsylvania')
# ('New Jersey', 'North Dakota')
# ('New Jersey', 'West Virginia')
# ('New Jersey', 'Illinois')
# ('New Jersey', 'Kentucky')
# ('New Jersey', 'Ohio')
# ('New Jersey', 'Pennsylvania')
# ('North Dakota', 'West Virginia')
# ('North Dakota', 'Illinois')
# ('North Dakota', 'Kentucky')
# ('North Dakota', 'Ohio')
# ('North Dakota', 'Pennsylvania')
# ('West Virginia', 'Illinois')
# ('West Virginia', 'Kentucky')
# ('West Virginia', 'Ohio')
# ('West Virginia', 'Pennsylvania')
# ('Illinois', 'Kentucky')
# ('Illinois', 'Ohio')
# ('Illinois', 'Pennsylvania')
# ('Kentucky', 'Ohio')
# ('Kentucky', 'Pennsylvania')
# ('Ohio', 'Pennsylvania')
# ('Indiana', 'Kansas')
# ('Indiana', 'Ohio')
# ('Kansas', 'Ohio')
# ('Massachusetts', 'Connecticut')
# ('Massachusetts', 'Virginia')
# ('Massachusetts', 'New Jersey')
# ('Connecticut', 'Virginia')
# ('Connecticut', 'New Jersey')
# ('Virginia', 'New Jersey')
# ('Texas', 'Michigan')
# ('Georgia', 'Missouri')
# ('Georgia', 'Arkansas')
# ('Missouri', 'Arkansas')
# ('Texas', 'Iowa')
# ('Colorado', 'West Virginia')
# ('Colorado', 'Montana')
# ('Colorado', 'Nevada')
# ('West Virginia', 'Montana')
# ('West Virginia', 'Nevada')
# ('Montana', 'Nevada')
# ('Missouri', 'Arkansas')
# ('North Carolina', 'Georgia')
# ('North Carolina', 'Iowa')
# ('North Carolina', 'Texas')
# ('North Carolina', 'Kansas')
# ('Georgia', 'Iowa')
# ('Georgia', 'Texas')
# ('Georgia', 'Kansas')
# ('Iowa', 'Texas')
# ('Iowa', 'Kansas')
# ('Texas', 'Kansas')
# ('Georgia', 'Missouri')
# ('Georgia', 'Wisconsin')
# ('Georgia', 'Arkansas')
# ('Georgia', 'Iowa')
# ('Georgia', 'Illinois')
# ('Georgia', 'West Virginia')
# ('Georgia', 'Michigan')
# ('Georgia', 'Tennessee')
# ('Georgia', 'Kentucky')
# ('Georgia', 'Indiana')
# ('Georgia', 'Ohio')
# ('Georgia', 'Florida')
# ('Georgia', 'New York')
# ('Georgia', 'Mississippi')
# ('Georgia', 'Pennsylvania')
# ('Georgia', 'Alabama')
# ('Missouri', 'Wisconsin')
# ('Missouri', 'Arkansas')
# ('Missouri', 'Iowa')
# ('Missouri', 'Illinois')
# ('Missouri', 'West Virginia')
# ('Missouri', 'Michigan')
# ('Missouri', 'Tennessee')
# ('Missouri', 'Kentucky')
# ('Missouri', 'Indiana')
# ('Missouri', 'Ohio')
# ('Missouri', 'Florida')
# ('Missouri', 'New York')
# ('Missouri', 'Mississippi')
# ('Missouri', 'Pennsylvania')
# ('Missouri', 'Alabama')
# ('Wisconsin', 'Arkansas')
# ('Wisconsin', 'Iowa')
# ('Wisconsin', 'Illinois')
# ('Wisconsin', 'West Virginia')
# ('Wisconsin', 'Michigan')
# ('Wisconsin', 'Tennessee')
# ('Wisconsin', 'Kentucky')
# ('Wisconsin', 'Indiana')
# ('Wisconsin', 'Ohio')
# ('Wisconsin', 'Florida')
# ('Wisconsin', 'New York')
# ('Wisconsin', 'Mississippi')
# ('Wisconsin', 'Pennsylvania')
# ('Wisconsin', 'Alabama')
# ('Arkansas', 'Iowa')
# ('Arkansas', 'Illinois')
# ('Arkansas', 'West Virginia')
# ('Arkansas', 'Michigan')
# ('Arkansas', 'Tennessee')
# ('Arkansas', 'Kentucky')
# ('Arkansas', 'Indiana')
# ('Arkansas', 'Ohio')
# ('Arkansas', 'Florida')
# ('Arkansas', 'New York')
# ('Arkansas', 'Mississippi')
# ('Arkansas', 'Pennsylvania')
# ('Arkansas', 'Alabama')
# ('Iowa', 'Illinois')
# ('Iowa', 'West Virginia')
# ('Iowa', 'Michigan')
# ('Iowa', 'Tennessee')
# ('Iowa', 'Kentucky')
# ('Iowa', 'Indiana')
# ('Iowa', 'Ohio')
# ('Iowa', 'Florida')
# ('Iowa', 'New York')
# ('Iowa', 'Mississippi')
# ('Iowa', 'Pennsylvania')
# ('Iowa', 'Alabama')
# ('Illinois', 'West Virginia')
# ('Illinois', 'Michigan')
# ('Illinois', 'Tennessee')
# ('Illinois', 'Kentucky')
# ('Illinois', 'Indiana')
# ('Illinois', 'Ohio')
# ('Illinois', 'Florida')
# ('Illinois', 'New York')
# ('Illinois', 'Mississippi')
# ('Illinois', 'Pennsylvania')
# ('Illinois', 'Alabama')
# ('West Virginia', 'Michigan')
# ('West Virginia', 'Tennessee')
# ('West Virginia', 'Kentucky')
# ('West Virginia', 'Indiana')
# ('West Virginia', 'Ohio')
# ('West Virginia', 'Florida')
# ('West Virginia', 'New York')
# ('West Virginia', 'Mississippi')
# ('West Virginia', 'Pennsylvania')
# ('West Virginia', 'Alabama')
# ('Michigan', 'Tennessee')
# ('Michigan', 'Kentucky')
# ('Michigan', 'Indiana')
# ('Michigan', 'Ohio')
# ('Michigan', 'Florida')
# ('Michigan', 'New York')
# ('Michigan', 'Mississippi')
# ('Michigan', 'Pennsylvania')
# ('Michigan', 'Alabama')
# ('Tennessee', 'Kentucky')
# ('Tennessee', 'Indiana')
# ('Tennessee', 'Ohio')
# ('Tennessee', 'Florida')
# ('Tennessee', 'New York')
# ('Tennessee', 'Mississippi')
# ('Tennessee', 'Pennsylvania')
# ('Tennessee', 'Alabama')
# ('Kentucky', 'Indiana')
# ('Kentucky', 'Ohio')
# ('Kentucky', 'Florida')
# ('Kentucky', 'New York')
# ('Kentucky', 'Mississippi')
# ('Kentucky', 'Pennsylvania')
# ('Kentucky', 'Alabama')
# ('Indiana', 'Ohio')
# ('Indiana', 'Florida')
# ('Indiana', 'New York')
# ('Indiana', 'Mississippi')
# ('Indiana', 'Pennsylvania')
# ('Indiana', 'Alabama')
# ('Ohio', 'Florida')
# ('Ohio', 'New York')
# ...
# ('Wisconsin', 'Arkansas')
# ('Wisconsin', 'Maryland')
# ('Wisconsin', 'Iowa')
# ('Wisconsin', 'Tennessee')
# ('Wisconsin', 'Ohio')
# ('Wisconsin', 'Florida')
# ('Wisconsin', 'Kansas')
# ('Wisconsin', 'Missouri')
# ('Wisconsin', 'Rhode Island')
# ('Wisconsin', 'Utah')
# ('Wisconsin', 'Kentucky')
# ('Wisconsin', 'Texas')
# ('Wisconsin', 'Idaho')
# ('Wisconsin', 'New York')
# ('Wisconsin', 'Minnesota')
# ('Wisconsin', 'Virginia')
# ('Wisconsin', 'Alabama')
# ('Wisconsin', 'North Carolina')
# ('Wisconsin', 'Colorado')
# ('Wisconsin', 'Louisiana')
# ('Wisconsin', 'Illinois')
# ('Wisconsin', 'Nebraska')
# ('Wisconsin', 'Indiana')
# ('Wisconsin', 'Oregon')
# ('Oklahoma', 'Vermont')
# ('Oklahoma', 'Mississippi')
# ('Oklahoma', 'Pennsylvania')
# ('Oklahoma', 'Maine')
# ('Oklahoma', 'Arkansas')
# ('Oklahoma', 'Maryland')
# ('Oklahoma', 'Iowa')
# ('Oklahoma', 'Tennessee')
# ('Oklahoma', 'Ohio')
# ('Oklahoma', 'Florida')
# ('Oklahoma', 'Kansas')
# ('Oklahoma', 'Missouri')
# ('Oklahoma', 'Rhode Island')
# ('Oklahoma', 'Utah')
# ('Oklahoma', 'Kentucky')
# ('Oklahoma', 'Texas')
# ('Oklahoma', 'Idaho')
# ('Oklahoma', 'New York')
# ('Oklahoma', 'Minnesota')
# ('Oklahoma', 'Virginia')
# ('Oklahoma', 'Alabama')
# ('Oklahoma', 'North Carolina')
# ('Oklahoma', 'Colorado')
# ('Oklahoma', 'Louisiana')
# ('Oklahoma', 'Illinois')
# ('Oklahoma', 'Nebraska')
# ('Oklahoma', 'Indiana')
# ('Oklahoma', 'Oregon')
# ('Vermont', 'Mississippi')
# ('Vermont', 'Pennsylvania')
# ('Vermont', 'Maine')
# ('Vermont', 'Arkansas')
# ('Vermont', 'Maryland')
# ('Vermont', 'Iowa')
# ('Vermont', 'Tennessee')
# ('Vermont', 'Ohio')
# ('Vermont', 'Florida')
# ('Vermont', 'Kansas')
# ('Vermont', 'Missouri')
# ('Vermont', 'Rhode Island')
# ('Vermont', 'Utah')
# ('Vermont', 'Kentucky')
# ('Vermont', 'Texas')
# ('Vermont', 'Idaho')
# ('Vermont', 'New York')
# ('Vermont', 'Minnesota')
# ('Vermont', 'Virginia')
# ('Vermont', 'Alabama')
# ('Vermont', 'North Carolina')
# ('Vermont', 'Colorado')
# ('Vermont', 'Louisiana')
# ('Vermont', 'Illinois')
# ('Vermont', 'Nebraska')
# ('Vermont', 'Indiana')
# ('Vermont', 'Oregon')
# ('Mississippi', 'Pennsylvania')
# ('Mississippi', 'Maine')
# ('Mississippi', 'Arkansas')
# ('Mississippi', 'Maryland')
# ('Mississippi', 'Iowa')
# ('Mississippi', 'Tennessee')
# ('Mississippi', 'Ohio')
# ('Mississippi', 'Florida')
# ('Mississippi', 'Kansas')
# ('Mississippi', 'Missouri')
# ('Mississippi', 'Rhode Island')
# ('Mississippi', 'Utah')
# ('Mississippi', 'Kentucky')
# ('Mississippi', 'Texas')
# ('Mississippi', 'Idaho')
# ('Mississippi', 'New York')
# ('Mississippi', 'Minnesota')
# ('Mississippi', 'Virginia')
# ('Mississippi', 'Alabama')
# ('Mississippi', 'North Carolina')
# ('Mississippi', 'Colorado')
# ('Mississippi', 'Louisiana')
# ('Mississippi', 'Illinois')
# ('Mississippi', 'Nebraska')
# ('Mississippi', 'Indiana')
# ('Mississippi', 'Oregon')
# ('Pennsylvania', 'Maine')
# ('Pennsylvania', 'Arkansas')
# ('Pennsylvania', 'Maryland')
# ('Pennsylvania', 'Iowa')
# ('Pennsylvania', 'Tennessee')
# ('Pennsylvania', 'Ohio')
# ('Pennsylvania', 'Florida')
# ('Pennsylvania', 'Kansas')
# ('Pennsylvania', 'Missouri')
# ('Pennsylvania', 'Rhode Island')
# ('Pennsylvania', 'Utah')
# ('Pennsylvania', 'Kentucky')
# ('Pennsylvania', 'Texas')
# ('Pennsylvania', 'Idaho')
# ('Pennsylvania', 'New York')
# ('Pennsylvania', 'Minnesota')
# ('Pennsylvania', 'Virginia')
# ('Pennsylvania', 'Alabama')
# ('Pennsylvania', 'North Carolina')
# ('Pennsylvania', 'Colorado')
# ('Pennsylvania', 'Louisiana')
# ('Pennsylvania', 'Illinois')
# ('Pennsylvania', 'Nebraska')
# ('Pennsylvania', 'Indiana')
# ('Pennsylvania', 'Oregon')
# ('Maine', 'Arkansas')
# ('Maine', 'Maryland')
# ('Maine', 'Iowa')
# ('Maine', 'Tennessee')
# ('Maine', 'Ohio')
# ('Maine', 'Florida')
# ('Maine', 'Kansas')
# ('Maine', 'Missouri')
# ('Maine', 'Rhode Island')
# ('Maine', 'Utah')
# ('Maine', 'Kentucky')
# ('Maine', 'Texas')
# ('Maine', 'Idaho')
# ('Maine', 'New York')
# ('Maine', 'Minnesota')
# ('Maine', 'Virginia')
# ('Maine', 'Alabama')
# ('Maine', 'North Carolina')
# ('Maine', 'Colorado')
# ('Maine', 'Louisiana')
# ('Maine', 'Illinois')
# ('Maine', 'Nebraska')
# ('Maine', 'Indiana')
# ('Maine', 'Oregon')
# ('Arkansas', 'Maryland')
# ('Arkansas', 'Iowa')
# ('Arkansas', 'Tennessee')
# ('Arkansas', 'Ohio')
# ('Arkansas', 'Florida')
# ('Arkansas', 'Kansas')
# ('Arkansas', 'Missouri')
# ('Arkansas', 'Rhode Island')
# ('Arkansas', 'Utah')
# ('Arkansas', 'Kentucky')
# ('Arkansas', 'Texas')
# ('Arkansas', 'Idaho')
# ('Arkansas', 'New York')
# ('Arkansas', 'Minnesota')
# ('Arkansas', 'Virginia')
# ('Arkansas', 'Alabama')
# ('Arkansas', 'North Carolina')
# ('Arkansas', 'Colorado')
# ('Arkansas', 'Louisiana')
# ('Arkansas', 'Illinois')
# ('Arkansas', 'Nebraska')
# ('Arkansas', 'Indiana')
# ('Arkansas', 'Oregon')
# ('Maryland', 'Iowa')
# ('Maryland', 'Tennessee')
# ('Maryland', 'Ohio')
# ('Maryland', 'Florida')
# ('Maryland', 'Kansas')
# ('Maryland', 'Missouri')
# ('Maryland', 'Rhode Island')
# ('Maryland', 'Utah')
# ('Maryland', 'Kentucky')
# ('Maryland', 'Texas')
# ('Maryland', 'Idaho')
# ('Maryland', 'New York')
# ('Maryland', 'Minnesota')
# ('Maryland', 'Virginia')
# ('Maryland', 'Alabama')
# ('Maryland', 'North Carolina')
# ('Maryland', 'Colorado')
# ('Maryland', 'Louisiana')
# ('Maryland', 'Illinois')
# ('Maryland', 'Nebraska')
# ('Maryland', 'Indiana')
# ('Maryland', 'Oregon')
# ('Iowa', 'Tennessee')
# ('Iowa', 'Ohio')
# ('Iowa', 'Florida')
# ('Iowa', 'Kansas')
# ('Iowa', 'Missouri')
# ('Iowa', 'Rhode Island')
# ('Iowa', 'Utah')
# ('Iowa', 'Kentucky')
# ('Iowa', 'Texas')
# ('Iowa', 'Idaho')
# ('Iowa', 'New York')
# ('Iowa', 'Minnesota')
# ('Iowa', 'Virginia')
# ('Iowa', 'Alabama')
# ('Iowa', 'North Carolina')
# ('Iowa', 'Colorado')
# ('Iowa', 'Louisiana')
# ('Iowa', 'Illinois')
# ('Iowa', 'Nebraska')
# ('Iowa', 'Indiana')
# ('Iowa', 'Oregon')
# ('Tennessee', 'Ohio')
# ('Tennessee', 'Florida')
# ('Tennessee', 'Kansas')
# ('Tennessee', 'Missouri')
# ('Tennessee', 'Rhode Island')
# ('Tennessee', 'Utah')
# ('Tennessee', 'Kentucky')
# ('Tennessee', 'Texas')
# ('Tennessee', 'Idaho')
# ('Tennessee', 'New York')
# ('Tennessee', 'Minnesota')
# ('Tennessee', 'Virginia')
# ('Tennessee', 'Alabama')
# ('Tennessee', 'North Carolina')
# ('Tennessee', 'Colorado')
# ('Tennessee', 'Louisiana')
# ('Tennessee', 'Illinois')
# ('Tennessee', 'Nebraska')
# ('Tennessee', 'Indiana')
# ('Tennessee', 'Oregon')
# ('Ohio', 'Florida')
# ('Ohio', 'Kansas')
# ('Ohio', 'Missouri')
# ('Ohio', 'Rhode Island')
# ('Ohio', 'Utah')
# ('Ohio', 'Kentucky')
# ('Ohio', 'Texas')
# ('Ohio', 'Idaho')
# ('Ohio', 'New York')
# ('Ohio', 'Minnesota')
# ('Ohio', 'Virginia')
# ('Ohio', 'Alabama')
# ('Ohio', 'North Carolina')
# ('Ohio', 'Colorado')
# ('Ohio', 'Louisiana')
# ('Ohio', 'Illinois')
# ('Ohio', 'Nebraska')
# ('Ohio', 'Indiana')
# ('Ohio', 'Oregon')
# ('Florida', 'Kansas')
# ('Florida', 'Missouri')
# ('Florida', 'Rhode Island')
# ('Florida', 'Utah')
# ('Florida', 'Kentucky')
# ('Florida', 'Texas')
# ('Florida', 'Idaho')
# ('Florida', 'New York')
# ('Florida', 'Minnesota')
# ('Florida', 'Virginia')
# ('Florida', 'Alabama')
# ('Florida', 'North Carolina')
# ('Florida', 'Colorado')
# ('Florida', 'Louisiana')
# ('Florida', 'Illinois')
# ('Florida', 'Nebraska')
# ('Florida', 'Indiana')
# ('Florida', 'Oregon')
# ('Kansas', 'Missouri')
# ('Kansas', 'Rhode Island')
# ('Kansas', 'Utah')
# ('Kansas', 'Kentucky')
# ('Kansas', 'Texas')
# ('Kansas', 'Idaho')
# ('Kansas', 'New York')
# ('Kansas', 'Minnesota')
# ('Kansas', 'Virginia')
# ('Kansas', 'Alabama')
# ('Kansas', 'North Carolina')
# ('Kansas', 'Colorado')
# ('Kansas', 'Louisiana')
# ('Kansas', 'Illinois')
# ('Kansas', 'Nebraska')
# ('Kansas', 'Indiana')
# ('Kansas', 'Oregon')
# ('Missouri', 'Rhode Island')
# ('Missouri', 'Utah')
# ('Missouri', 'Kentucky')
# ('Missouri', 'Texas')
# ('Missouri', 'Idaho')
# ('Missouri', 'New York')
# ('Missouri', 'Minnesota')
# ('Missouri', 'Virginia')
# ('Missouri', 'Alabama')
# ('Missouri', 'North Carolina')
# ('Missouri', 'Colorado')
# ('Missouri', 'Louisiana')
# ('Missouri', 'Illinois')
# ('Missouri', 'Nebraska')
# ('Missouri', 'Indiana')
# ('Missouri', 'Oregon')
# ('Rhode Island', 'Utah')
# ('Rhode Island', 'Kentucky')
# ('Rhode Island', 'Texas')
# ('Rhode Island', 'Idaho')
# ('Rhode Island', 'New York')
# ('Rhode Island', 'Minnesota')
# ('Rhode Island', 'Virginia')
# ('Rhode Island', 'Alabama')
# ('Rhode Island', 'North Carolina')
# ('Rhode Island', 'Colorado')
# ('Rhode Island', 'Louisiana')
# ('Rhode Island', 'Illinois')
# ('Rhode Island', 'Nebraska')
# ('Rhode Island', 'Indiana')
# ('Rhode Island', 'Oregon')
# ('Utah', 'Kentucky')
# ('Utah', 'Texas')
# ('Utah', 'Idaho')
# ('Utah', 'New York')
# ('Utah', 'Minnesota')
# ('Utah', 'Virginia')
# ('Utah', 'Alabama')
# ('Utah', 'North Carolina')
# ('Utah', 'Colorado')
# ('Utah', 'Louisiana')
# ('Utah', 'Illinois')
# ('Utah', 'Nebraska')
# ('Utah', 'Indiana')
# ('Utah', 'Oregon')
# ('Kentucky', 'Texas')
# ('Kentucky', 'Idaho')
# ('Kentucky', 'New York')
# ('Kentucky', 'Minnesota')
# ('Kentucky', 'Virginia')
# ('Kentucky', 'Alabama')
# ('Kentucky', 'North Carolina')
# ('Kentucky', 'Colorado')
# ('Kentucky', 'Louisiana')
# ('Kentucky', 'Illinois')
# ('Kentucky', 'Nebraska')
# ('Kentucky', 'Indiana')
# ('Kentucky', 'Oregon')
# ('Texas', 'Idaho')
# ('Texas', 'New York')
# ('Texas', 'Minnesota')
# ('Texas', 'Virginia')
# ('Texas', 'Alabama')
# ('Texas', 'North Carolina')
# ('Texas', 'Colorado')
# ('Texas', 'Louisiana')
# ('Texas', 'Illinois')
# ('Texas', 'Nebraska')
# ('Texas', 'Indiana')
# ('Texas', 'Oregon')
# ('Idaho', 'New York')
# ('Idaho', 'Minnesota')
# ('Idaho', 'Virginia')
# ('Idaho', 'Alabama')
# ('Idaho', 'North Carolina')
# ('Idaho', 'Colorado')
# ('Idaho', 'Louisiana')
# ('Idaho', 'Illinois')
# ('Idaho', 'Nebraska')
# ('Idaho', 'Indiana')
# ('Idaho', 'Oregon')
# ('New York', 'Minnesota')
# ('New York', 'Virginia')
# ('New York', 'Alabama')
# ('New York', 'North Carolina')
# ('New York', 'Colorado')
# ('New York', 'Louisiana')
# ('New York', 'Illinois')
# ('New York', 'Nebraska')
# ('New York', 'Indiana')
# ('New York', 'Oregon')
# ('Minnesota', 'Virginia')
# ('Minnesota', 'Alabama')
# ('Minnesota', 'North Carolina')
# ('Minnesota', 'Colorado')
# ('Minnesota', 'Louisiana')
# ('Minnesota', 'Illinois')
# ('Minnesota', 'Nebraska')
# ('Minnesota', 'Indiana')
# ('Minnesota', 'Oregon')
# ('Virginia', 'Alabama')
# ('Virginia', 'North Carolina')
# ('Virginia', 'Colorado')
# ('Virginia', 'Louisiana')
# ('Virginia', 'Illinois')
# ('Virginia', 'Nebraska')
# ('Virginia', 'Indiana')
# ('Virginia', 'Oregon')
# ('Alabama', 'North Carolina')
# ('Alabama', 'Colorado')
# ('Alabama', 'Louisiana')
# ('Alabama', 'Illinois')
# ('Alabama', 'Nebraska')
# ('Alabama', 'Indiana')
# ('Alabama', 'Oregon')
# ('North Carolina', 'Colorado')
# ('North Carolina', 'Louisiana')
# ('North Carolina', 'Illinois')
# ('North Carolina', 'Nebraska')
# ('North Carolina', 'Indiana')
# ('North Carolina', 'Oregon')
# ('Colorado', 'Louisiana')
# ('Colorado', 'Illinois')
# ('Colorado', 'Nebraska')
# ('Colorado', 'Indiana')
# ('Colorado', 'Oregon')
# ('Louisiana', 'Illinois')
# ('Louisiana', 'Nebraska')
# ('Louisiana', 'Indiana')
# ('Louisiana', 'Oregon')
# ('Illinois', 'Nebraska')
# ('Illinois', 'Indiana')
# ('Illinois', 'Oregon')
# ('Nebraska', 'Indiana')
# ('Nebraska', 'Oregon')
# ('Indiana', 'Oregon')
# ('North Carolina', 'Georgia')
# ('North Carolina', 'Missouri')
# ('North Carolina', 'Iowa')
# ('North Carolina', 'West Virginia')
# ('North Carolina', 'Nebraska')
# ('North Carolina', 'Michigan')
# ('North Carolina', 'Illinois')
# ('North Carolina', 'Tennessee')
# ('North Carolina', 'Utah')
# ('North Carolina', 'Kentucky')
# ('North Carolina', 'Indiana')
# ('North Carolina', 'Ohio')
# ('North Carolina', 'New York')
# ('North Carolina', 'Mississippi')
# ('North Carolina', 'Pennsylvania')
# ('Georgia', 'Missouri')
# ('Georgia', 'Iowa')
# ('Georgia', 'West Virginia')
# ('Georgia', 'Nebraska')
# ('Georgia', 'Michigan')
# ('Georgia', 'Illinois')
# ('Georgia', 'Tennessee')
# ('Georgia', 'Utah')
# ('Georgia', 'Kentucky')
# ('Georgia', 'Indiana')
# ('Georgia', 'Ohio')
# ('Georgia', 'New York')
# ('Georgia', 'Mississippi')
# ('Georgia', 'Pennsylvania')
# ('Missouri', 'Iowa')
# ('Missouri', 'West Virginia')
# ('Missouri', 'Nebraska')
# ('Missouri', 'Michigan')
# ('Missouri', 'Illinois')
# ('Missouri', 'Tennessee')
# ('Missouri', 'Utah')
# ('Missouri', 'Kentucky')
# ('Missouri', 'Indiana')
# ('Missouri', 'Ohio')
# ('Missouri', 'New York')
# ('Missouri', 'Mississippi')
# ('Missouri', 'Pennsylvania')
# ('Iowa', 'West Virginia')
# ('Iowa', 'Nebraska')
# ('Iowa', 'Michigan')
# ('Iowa', 'Illinois')
# ('Iowa', 'Tennessee')
# ('Iowa', 'Utah')
# ('Iowa', 'Kentucky')
# ('Iowa', 'Indiana')
# ('Iowa', 'Ohio')
# ('Iowa', 'New York')
# ('Iowa', 'Mississippi')
# ('Iowa', 'Pennsylvania')
# ('West Virginia', 'Nebraska')
# ('West Virginia', 'Michigan')
# ('West Virginia', 'Illinois')
# ('West Virginia', 'Tennessee')
# ('West Virginia', 'Utah')
# ('West Virginia', 'Kentucky')
# ('West Virginia', 'Indiana')
# ('West Virginia', 'Ohio')
# ('West Virginia', 'New York')
# ('West Virginia', 'Mississippi')
# ('West Virginia', 'Pennsylvania')
# ('Nebraska', 'Michigan')
# ('Nebraska', 'Illinois')
# ('Nebraska', 'Tennessee')
# ('Nebraska', 'Utah')
# ('Nebraska', 'Kentucky')
# ('Nebraska', 'Indiana')
# ('Nebraska', 'Ohio')
# ('Nebraska', 'New York')
# ('Nebraska', 'Mississippi')
# ('Nebraska', 'Pennsylvania')
# ('Michigan', 'Illinois')
# ('Michigan', 'Tennessee')
# ('Michigan', 'Utah')
# ('Michigan', 'Kentucky')
# ('Michigan', 'Indiana')
# ('Michigan', 'Ohio')
# ('Michigan', 'New York')
# ('Michigan', 'Mississippi')
# ('Michigan', 'Pennsylvania')
# ('Illinois', 'Tennessee')
# ('Illinois', 'Utah')
# ('Illinois', 'Kentucky')
# ('Illinois', 'Indiana')
# ('Illinois', 'Ohio')
# ('Illinois', 'New York')
# ('Illinois', 'Mississippi')
# ('Illinois', 'Pennsylvania')
# ('Tennessee', 'Utah')
# ('Tennessee', 'Kentucky')
# ('Tennessee', 'Indiana')
# ('Tennessee', 'Ohio')
# ('Tennessee', 'New York')
# ('Tennessee', 'Mississippi')
# ('Tennessee', 'Pennsylvania')
# ('Utah', 'Kentucky')
# ('Utah', 'Indiana')
# ('Utah', 'Ohio')
# ('Utah', 'New York')
# ('Utah', 'Mississippi')
# ('Utah', 'Pennsylvania')
# ('Kentucky', 'Indiana')
# ('Kentucky', 'Ohio')
# ('Kentucky', 'New York')
# ('Kentucky', 'Mississippi')
# ('Kentucky', 'Pennsylvania')
# ('Indiana', 'Ohio')
# ('Indiana', 'New York')
# ('Indiana', 'Mississippi')
# ('Indiana', 'Pennsylvania')
# ('Ohio', 'New York')
# ('Ohio', 'Mississippi')
# ('Ohio', 'Pennsylvania')
# ('New York', 'Mississippi')
# ('New York', 'Pennsylvania')
# ('Mississippi', 'Pennsylvania')
# ('Georgia', 'Missouri')
# ('Georgia', 'Iowa')
# ('Georgia', 'Louisiana')
# ('Georgia', 'Nebraska')
# ('Georgia', 'West Virginia')
# ('Georgia', 'Kentucky')
# ('Georgia', 'Mississippi')
# ('Missouri', 'Iowa')
# ('Missouri', 'Louisiana')
# ('Missouri', 'Nebraska')
# ('Missouri', 'West Virginia')
# ('Missouri', 'Kentucky')
# ('Missouri', 'Mississippi')
# ('Iowa', 'Louisiana')
# ('Iowa', 'Nebraska')
# ('Iowa', 'West Virginia')
# ('Iowa', 'Kentucky')
# ('Iowa', 'Mississippi')
# ('Louisiana', 'Nebraska')
# ('Louisiana', 'West Virginia')
# ('Louisiana', 'Kentucky')
# ('Louisiana', 'Mississippi')
# ('Nebraska', 'West Virginia')
# ('Nebraska', 'Kentucky')
# ('Nebraska', 'Mississippi')
# ('West Virginia', 'Kentucky')
# ('West Virginia', 'Mississippi')
# ('Kentucky', 'Mississippi')
# ('Indiana', 'North Dakota')
# ('Pennsylvania', 'Virginia')
# ('Texas', 'Georgia')
# ('Texas', 'Nebraska')
# ('Texas', 'Oregon')
# ('Georgia', 'Nebraska')
# ('Georgia', 'Oregon')
# ('Nebraska', 'Oregon')
# ('Georgia', 'Arkansas')
# ('Georgia', 'Illinois')
# ('Georgia', 'Tennessee')
# ('Georgia', 'Indiana')
# ('Arkansas', 'Illinois')
# ('Arkansas', 'Tennessee')
# ('Arkansas', 'Indiana')
# ('Illinois', 'Tennessee')
# ('Illinois', 'Indiana')
# ('Tennessee', 'Indiana')
# ('Indiana', 'Kentucky')
# ('Texas', 'Kansas')
# ('Georgia', 'Alabama')
# ('North Carolina', 'Georgia')
# ('Georgia', 'Mississippi')
# ('North Dakota', 'Ohio')
# ('Texas', 'Illinois')
# ('Texas', 'Tennessee')
# ('Illinois', 'Tennessee')
# ('Texas', 'North Carolina')
# ('Texas', 'Tennessee')
# ('Texas', 'Kansas')
# ('North Carolina', 'Tennessee')
# ('North Carolina', 'Kansas')
# ('Tennessee', 'Kansas')
# ('Vermont', 'Connecticut')
# ('Illinois', 'Wisconsin')
# ('Illinois', 'Iowa')
# ('Wisconsin', 'Iowa')
# ('Alabama', 'Mississippi')
# ('Texas', 'Virginia')
# ('Texas', 'West Virginia')
# ('Texas', 'Wisconsin')
# ('Texas', 'Ohio')
# ('West Virginia', 'Wisconsin')
# ('West Virginia', 'Ohio')
# ('Wisconsin', 'Ohio')
# ('Illinois', 'Kentucky')
# ('Massachusetts', 'Maryland')
# ('Georgia', 'Missouri')
# ('Georgia', 'Iowa')
# ('Missouri', 'Iowa')
# ('Minnesota', 'Missouri')
# ('Minnesota', 'Iowa')
# ('Missouri', 'Iowa')
# ('West Virginia', 'Pennsylvania')
# ('West Virginia', 'New York')
# ('Pennsylvania', 'New York')
# ('Maine', 'Nebraska')
# ('Maine', 'South Carolina')
# ('Maine', 'Pennsylvania')
# ('Maine', 'Virginia')
# ('Nebraska', 'South Carolina')
# ('Nebraska', 'Pennsylvania')
# ('Nebraska', 'Virginia')
# ('South Carolina', 'Pennsylvania')
# ('South Carolina', 'Virginia')
# ('Pennsylvania', 'Virginia')
# ('Colorado', 'Arizona')

# %% [markdown]
# Print list of Top N states by the least number of death in a specific year. Also needed to be ranked.
#
# Top 10 least death states in 2020

# %%
df_2020 = merge[merge['year'] == 2020]
state_deaths = df_2020.groupby('state')['deaths'].sum().reset_index()
top_10_states = state_deaths.sort_values('deaths', ascending=True).head(10)
top_10_states['rank'] = top_10_states['deaths'].rank(method='min', ascending=True).astype(int)
print(top_10_states[[ 'state', 'deaths','rank']])
# Out:
#                        state  deaths  rank
# 36  Northern Mariana Islands   108.0     1
# 49            Virgin Islands   198.0     2
# 54                   Wyoming   320.0     3
# 11                      Guam   335.0     4
# 1                     Alaska   400.0     5
# 27                   Montana   743.0     6
# 12                    Hawaii   749.0     7
# 44              South Dakota  1274.0     8
# 35              North Dakota  1386.0     9
# 52             West Virginia  2171.0    10
#                        state  deaths  rank
# 36  Northern Mariana Islands   108.0     1
# 49            Virgin Islands   198.0     2
# 54                   Wyoming   320.0     3
# 11                      Guam   335.0     4
# 1                     Alaska   400.0     5
# 27                   Montana   743.0     6
# 12                    Hawaii   749.0     7
# 44              South Dakota  1274.0     8
# 35              North Dakota  1386.0     9
# 52             West Virginia  2171.0    10

# %% [markdown]
# Top 10 least death states in 2021

# %%
df_2021 = merge[merge['year'] == 2021]
state_deaths = df_2021.groupby('state')['deaths'].sum().reset_index()
top_10_states = state_deaths.sort_values('deaths', ascending=True).head(10)
top_10_states['rank'] = top_10_states['deaths'].rank(method='min', ascending=True).astype(int)
print(top_10_states[[ 'state', 'deaths','rank']])
# Out:
#                        state   deaths  rank
# 2             American Samoa      0.0     1
# 37  Northern Mariana Islands    173.0     2
# 50            Virgin Islands   1848.0     3
# 12                      Guam   5678.0     4
# 49                   Vermont   9516.0     5
# 1                     Alaska  19316.0     6
# 13                    Hawaii  22462.0     7
# 9       District of Columbia  25324.0     8
# 21                     Maine  30376.0     9
# 55                   Wyoming  31716.0    10

# %% [markdown]
# Print Top N states in the last three months of the year 2021. Also needed to be ranked. Also right this output as a file in folder /content/drive/MyDrive/data_preprocessing with header and no index.
# a) Top 10 least death states in last three months of the year 2021

# %%
df_last_three_months = merge[(merge['date'].dt.year == 2021) & (merge['date'].dt.month >= 10)]
state_deaths = df_last_three_months.groupby('state')['deaths'].sum().reset_index()
top_10_states = state_deaths.sort_values('deaths', ascending=True).head(10)
top_10_states['rank'] = top_10_states['deaths'].rank(method='min', ascending=True).astype(float)
top_10_states = top_10_states.rename(columns={'deaths': 'Total_Deaths_2021'})
print('Top 10 least death states in last three months of the year 2021 as belows:')
print(top_10_states[['state', 'Total_Deaths_2021','rank']].to_string(index=False))
# Out:
# Top 10 least death states in last three months of the year 2021 as belows:
#                    state  Total_Deaths_2021  rank
#           American Samoa                0.0   1.0
# Northern Mariana Islands              173.0   2.0
#           Virgin Islands             1848.0   3.0
#                     Guam             5678.0   4.0
#                  Vermont             9516.0   5.0
#                   Alaska            19316.0   6.0
#                   Hawaii            22462.0   7.0
#     District of Columbia            25324.0   8.0
#                    Maine            30376.0   9.0
#                  Wyoming            31716.0  10.0

# %% [markdown]
# b) Top 10 most death states in last three months of the year 2021

# %%
df_last_three_months = merge[(merge['date'].dt.year == 2021) & (merge['date'].dt.month >= 10)]
state_deaths = df_last_three_months.groupby('state')['deaths'].sum().reset_index()
top_10_states = state_deaths.sort_values('deaths', ascending=True).head(10)
top_10_states['rank'] = top_10_states['deaths'].rank(method='max', ascending=True).astype(float)
top_10_states = top_10_states.rename(columns={'deaths': 'Total_Deaths_2021'})
print('Top 10 most death states in last three months of the year 2021 as belows:')
print(top_10_states[['state', 'Total_Deaths_2021','rank']].to_string(index=False))
# Out:
# Top 10 most death states in last three months of the year 2021 as belows:
#                    state  Total_Deaths_2021  rank
#           American Samoa                0.0   1.0
# Northern Mariana Islands              173.0   2.0
#           Virgin Islands             1848.0   3.0
#                     Guam             5678.0   4.0
#                  Vermont             9516.0   5.0
#                   Alaska            19316.0   6.0
#                   Hawaii            22462.0   7.0
#     District of Columbia            25324.0   8.0
#                    Maine            30376.0   9.0
#                  Wyoming            31716.0  10.0
